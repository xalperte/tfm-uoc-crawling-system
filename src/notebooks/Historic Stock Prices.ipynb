# %% [markdown]
# # Historical Stock Prices
#
# We need to get the stock prices of all the companies for which we have fundamental data.
#
# We will use this information to compute returns, and fundamental metrics.
#
# We will relay on the package YahooFinancials in order to get the ticker prices.

# %%
from yahoofinancials import YahooFinancials
import pandas as pd

# %%
# Load all the companies tickers and pivot by ticker_type
original_tickers_df = pd.read_csv('tickers.csv', header=None, names=["ccvm", "ticker", "ticker_type"])
tickers_df = pd.pivot(original_tickers_df, index='ccvm', columns='ticker_type', values='ticker')
tickers_df = tickers_df.add_prefix("ticker_type_")
tickers_df
# Out:
# ticker_type ticker_type_3 ticker_type_4 ticker_type_5 ticker_type_6
# ccvm
# 94                  PATI3         PATI4           NaN           NaN
# 531                 ARTR3           NaN           NaN           NaN
# 574                 ARLA3         ARLA4           NaN           NaN
# 701                 BAHI3           NaN           NaN           NaN
# 906                 BBDC3         BBDC4           NaN           NaN
# ...                   ...           ...           ...           ...
# 23612               MSRO3           NaN           NaN           NaN
# 23710               HCBR3           NaN           NaN           NaN
# 23728               PRCA3           NaN           NaN           NaN
# 24783               NTCO3           NaN           NaN           NaN
# 24805               VIVA3           NaN           NaN           NaN
#
# [409 rows x 4 columns]

# %% [markdown]
# ## Ticker Types
#
# In the cash market, tickers are composed by four letters, a number, and a suffix in some cases. The letters stand for the listed company and the number disclosed the equity type, as follows
#
# |  Number |  Class | Trade name indication
# |---|---|---|
# | 3 | common share | ON (''ordinária nominativa'') |
# | 4 | preferred share | PN (''preferencial nominativa'') |
# | 5 | preferred share class A | PNA |
# | 6 | preferred share class B | PNB |
#
# In order to get the stock prices, we are going to start with the ON ticker, and then try with the PN, PNA, and PNB.

# %%
# Initialize DSE Cluster connection
try:
    from dse.cluster import Cluster
except ImportError:
    from cassandra.cluster import Cluster

cluster = Cluster(['tfm_uoc_dse'])  # provide contact points and port
session = cluster.connect('tfm_uoc')

# %%
original_companies_df = session.execute("select ccvm, company_name, cnpj from bovespa_company;")
original_companies_df = pd.DataFrame(
    [{
        "ccvm": int(x.ccvm), 
        "company_name": x.company_name,
        "cnpj": x.cnpj} 
            for x in list(original_companies_df)])

# %%
def get_companies_accounts(session):
    """
    This function computes the total number of financial accounts
    informed by company.
    
    It returns a pandas dataframe with the company id (ccvm)
    and the number of accounts.
    """
    import json

    solr_query = {
        "q": "*:*",
        "facet": {
            "field": "ccvm_exact",
            "limit": 10000
        }
    }

    accounts_per_company_query = \
        f"select * from bovespa_account WHERE solr_query='{json.dumps(solr_query)}'"

    accounts_per_company = session.execute(accounts_per_company_query).one()
    accounts_per_company = json.loads(accounts_per_company.facet_fields)["ccvm_exact"]
    accounts_per_company = pd.DataFrame([{
        "ccvm": int(ccvm), 
        "num_accounts": num_accounts } 
            for ccvm, num_accounts in accounts_per_company.items()])
    display("Total number of companies: {}".format(len(accounts_per_company)))
    return accounts_per_company

# %%
# Obtain all the companies with fundamental data 
companies_with_fundamentals_df = get_companies_accounts(session)
companies_with_fundamentals_df.head(10)
# Out:
# 'Total number of companies: 782'
#     ccvm  num_accounts
# 0  11070         48111
# 1  21067         44244
# 2  20010         43019
# 3  20931         42939
# 4  22020         41496
# 5  15253         40267
# 6  21636         39393
# 7  17450         38341
# 8  21490         38089
# 9  19569         38064

# %%
# Compute the ticker for each company (CCVM)
companies_df = pd.merge(left=companies_with_fundamentals_df, 
                        right=original_companies_df, 
                        how='left', 
                        left_on='ccvm', 
                        right_on='ccvm')

companies_df = pd.merge(left=companies_df, 
                        right=tickers_df, 
                        how='left', 
                        left_on='ccvm', 
                        right_on='ccvm')

companies_df.head(10)
# Out:
#     ccvm  num_accounts                       company_name                cnpj  \
# 0  11070         48111      WLM INDÚSTRIA E COMÉRCIO S.A.  33.228.024/0001-51
# 1  21067         44244        MOURA DUBEUX ENGENHARIA S/A  12.049.631/0001-84
# 2  20010         43019             EQUATORIAL ENERGIA S/A  03.220.438/0001-73
# 3  20931         42939                        MINERVA S/A  67.620.377/0001-14
# 4  22020         41496                           JSL S.A.  52.548.435/0001-79
# 5  15253         40267                        ENERGISA SA  00.864.214/0001-06
# 6  21636         39393                 RENOVA ENERGIA S/A  08.534.605/0001-74
# 7  17450         38341                          RUMO S.A.  02.387.241/0001-60
# 8  21490         38089            ALUPAR INVESTIMENTO S/A  08.364.948/0001-38
# 9  19569         38064  GOL LINHAS AEREAS INTELIGENTES SA  06.164.253/0001-87
#
#   ticker_type_3 ticker_type_4 ticker_type_5 ticker_type_6
# 0         SGAS3         SGAS4           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2         EQTL3           NaN           NaN           NaN
# 3         BEEF3           NaN           NaN           NaN
# 4         JSLG3           NaN           NaN           NaN
# 5         ENGI3         ENGI4           NaN           NaN
# 6         RNEW3         RNEW4           NaN           NaN
# 7           NaN           NaN           NaN           NaN
# 8         ALUP3         ALUP4           NaN           NaN
# 9           NaN         GOLL4           NaN           NaN

# %%
companies_no_ticker_df = companies_df[(pd.isnull(companies_df["ticker_type_3"])) & 
                                      (pd.isnull(companies_df["ticker_type_4"])) &
                                      (pd.isnull(companies_df["ticker_type_5"])) &
                                      (pd.isnull(companies_df["ticker_type_6"]))]
companies_no_ticker_df = companies_no_ticker_df.sort_values(['ccvm'], ascending=[1])
print(f"Companies without Ticker Info: {companies_no_ticker_df.count()}")
# Out:
# Companies without Ticker Info: ccvm             454
# num_accounts     454
# company_name     454
# cnpj             454
# ticker_type_3      0
# ticker_type_4      0
# ticker_type_5      0
# ticker_type_6      0
# dtype: int64

# %%
companies_ticker_df = companies_df[(pd.notnull(companies_df["ticker_type_3"])) |
                                      (pd.notnull(companies_df["ticker_type_4"])) |
                                      (pd.notnull(companies_df["ticker_type_5"])) |
                                      (pd.notnull(companies_df["ticker_type_6"]))]
companies_ticker_df = companies_ticker_df.sort_values(['ccvm'], ascending=[1])
print(f"Companies with Ticker Info: {companies_ticker_df.count()}")
# Out:
# Companies with Ticker Info: ccvm             328
# num_accounts     328
# company_name     328
# cnpj             328
# ticker_type_3    326
# ticker_type_4    111
# ticker_type_5     24
# ticker_type_6      1
# dtype: int64

# %% [raw]
# # Get all the tickers from which we will get historic prices
# tickers = companies_df.ticker[pd.notna(companies_df.ticker)]

# %%
# for index, ticker in enumerate(tickers.to_list()):
company_stock_prices = {}
for index, row in companies_ticker_df.iterrows():
    available_tickers = []
    if pd.notna(row["ticker_type_3"]):
        available_tickers.append("ticker_type_3")
    if pd.notna(row["ticker_type_4"]):
        available_tickers.append("ticker_type_4")
    if pd.notna(row["ticker_type_5"]):
        available_tickers.append("ticker_type_5")
    if pd.notna(row["ticker_type_6"]):
        available_tickers.append("ticker_type_6")

    for ticker_column in available_tickers:    
        ticker = row[ticker_column]
        print(f"Getting ticker [{index}]: {ticker}.SA")
        yahoo_financials = YahooFinancials(f"{ticker}.SA")
        historical_stock_prices = yahoo_financials.get_historical_price_data('2000-01-01', '2020-01-03', 'daily')
        company_stock_prices[ticker] = historical_stock_prices[f"{ticker}.SA"]
# Out:
# Getting ticker [86]: BBAS3.SA
# Getting ticker [459]: BGIP3.SA
# Getting ticker [459]: BGIP4.SA
# Getting ticker [144]: BEES3.SA
# Getting ticker [144]: BEES4.SA
# Getting ticker [616]: BPAR3.SA
# Getting ticker [194]: BRSR3.SA
# Getting ticker [194]: BRSR5.SA
# Getting ticker [277]: BNBR3.SA
# Getting ticker [453]: BMIN3.SA
# Getting ticker [453]: BMIN4.SA
# Getting ticker [175]: BMEB3.SA
# Getting ticker [175]: BMEB4.SA
# Getting ticker [215]: BRIV3.SA
# Getting ticker [215]: BRIV4.SA
# Getting ticker [77]: BDLL3.SA
# Getting ticker [77]: BDLL4.SA
# Getting ticker [229]: BALM3.SA
# Getting ticker [229]: BALM4.SA
# Getting ticker [314]: BAUH3.SA
# Getting ticker [314]: BAUH4.SA
# Getting ticker [131]: BMKS3.SA
# Getting ticker [460]: BMTO3.SA
# Getting ticker [460]: BMTO4.SA
# Getting ticker [684]: BUET3.SA
# Getting ticker [684]: BUET4.SA
# Getting ticker [530]: CAMB3.SA
# Getting ticker [530]: CAMB4.SA
# Getting ticker [519]: RANI3.SA
# Getting ticker [519]: RANI4.SA
# Getting ticker [103]: CMIG3.SA
# Getting ticker [103]: CMIG4.SA
# Getting ticker [62]: CLSC3.SA
# Getting ticker [62]: CLSC4.SA
# Getting ticker [240]: CBEE3.SA
# Getting ticker [81]: FESA3.SA
# Getting ticker [81]: FESA4.SA
# Getting ticker [403]: CEDO3.SA
# Getting ticker [403]: CEDO4.SA
# Getting ticker [120]: CSAB3.SA
# Getting ticker [120]: CSAB4.SA
# Getting ticker [476]: CTNM3.SA
# Getting ticker [476]: CTNM4.SA
# Getting ticker [281]: IMBI3.SA
# Getting ticker [281]: IMBI4.SA
# Getting ticker [22]: REDE3.SA
# Getting ticker [22]: REDE4.SA
# Getting ticker [75]: EEEL3.SA
# Getting ticker [75]: EEEL4.SA
# Getting ticker [193]: HBTS3.SA
# Getting ticker [193]: HBTS5.SA
# Getting ticker [520]: CATA3.SA
# Getting ticker [520]: CATA4.SA
# Getting ticker [115]: SCLO3.SA
# Getting ticker [115]: SCLO4.SA
# Getting ticker [119]: MSPA3.SA
# Getting ticker [119]: MSPA4.SA
# Getting ticker [386]: CRIV3.SA
# Getting ticker [386]: CRIV4.SA
# Getting ticker [204]: GGBR3.SA
# Getting ticker [204]: GGBR4.SA
# Getting ticker [64]: CSNA3.SA
# Getting ticker [293]: CRUZ3.SA
# Getting ticker [221]: CTSA3.SA
# Getting ticker [221]: CTSA4.SA
# Getting ticker [507]: CTKA3.SA
# Getting ticker [507]: CTKA4.SA
# Getting ticker [70]: VALE3.SA
# Getting ticker [70]: VALE5.SA
# Getting ticker [265]: ELEK3.SA
# Getting ticker [265]: ELEK4.SA
# Getting ticker [303]: CBMA3.SA
# Getting ticker [303]: CBMA4.SA
# Getting ticker [443]: CGRA3.SA
# Getting ticker [443]: CGRA4.SA
# Getting ticker [49]: GUAR3.SA
# Getting ticker [49]: GUAR4.SA
# Getting ticker [377]: ODER3.SA
# Getting ticker [377]: ODER4.SA
# Getting ticker [538]: BRGE3.SA
# Getting ticker [538]: BRGE5.SA
# Getting ticker [674]: COBE3B.SA
# Getting ticker [674]: COBE5B.SA
# Getting ticker [492]: LIXC3.SA
# Getting ticker [492]: LIXC4.SA
# Getting ticker [408]: MEND3.SA
# Getting ticker [408]: MEND5.SA
# Getting ticker [445]: BRKM3.SA
# Getting ticker [445]: BRKM5.SA
# Getting ticker [578]: CORR3.SA
# Getting ticker [578]: CORR4.SA
# Getting ticker [494]: DHBI3.SA
# Getting ticker [494]: DHBI4.SA
# Getting ticker [33]: ALPA3.SA
# Getting ticker [33]: ALPA4.SA
# Getting ticker [113]: SLED3.SA
# Getting ticker [113]: SLED4.SA
# Getting ticker [345]: SGEN3.SA
# Getting ticker [345]: SGEN4.SA
# Getting ticker [11]: SOND3.SA
# Getting ticker [11]: SOND5.SA
# Getting ticker [100]: SPRI3.SA
# Getting ticker [100]: SPRI5.SA
# Getting ticker [0]: SGAS3.SA
# Getting ticker [0]: SGAS4.SA
# Getting ticker [536]: TCNO3.SA
# Getting ticker [536]: TCNO4.SA
# Getting ticker [335]: TENE3.SA
# Getting ticker [335]: TENE5.SA
# Getting ticker [132]: TEKA3.SA
# Getting ticker [132]: TEKA4.SA
# Getting ticker [65]: TKNO3.SA
# Getting ticker [65]: TKNO4.SA
# Getting ticker [104]: TELB3.SA
# Getting ticker [104]: TELB4.SA
# Getting ticker [43]: OIBR3.SA
# Getting ticker [43]: OIBR4.SA
# Getting ticker [26]: CRPG3.SA
# Getting ticker [26]: CRPG5.SA
# Getting ticker [91]: UNIP3.SA
# Getting ticker [91]: UNIP5.SA
# Getting ticker [91]: UNIP6.SA
# Getting ticker [436]: VULC3.SA
# Getting ticker [372]: WMBY3.SA
# Getting ticker [139]: MYPK3.SA
# Getting ticker [148]: AZEV3.SA
# Getting ticker [148]: AZEV4.SA
# Getting ticker [222]: MWET3.SA
# Getting ticker [222]: MWET4.SA
# Getting ticker [36]: BOBR3.SA
# Getting ticker [36]: BOBR4.SA
# Getting ticker [178]: LFFE3.SA
# Getting ticker [178]: LFFE4.SA
# Getting ticker [177]: JBDU3.SA
# Getting ticker [177]: JBDU4.SA
# Getting ticker [213]: ITEC3.SA
# Getting ticker [201]: RCSL3.SA
# Getting ticker [201]: RCSL4.SA
# Getting ticker [462]: KLBN3.SA
# Getting ticker [462]: KLBN4.SA
# Getting ticker [134]: SNSY3.SA
# Getting ticker [134]: SNSY5.SA
# Getting ticker [434]: FIBR3.SA
# Getting ticker [140]: APTI3.SA
# Getting ticker [140]: APTI4.SA
# Getting ticker [651]: REEM3.SA
# Getting ticker [651]: REEM4.SA
# Getting ticker [146]: SULT3.SA
# Getting ticker [146]: SULT4.SA
# Getting ticker [63]: JOPA3.SA
# Getting ticker [63]: JOPA4.SA
# Getting ticker [200]: HAGA3.SA
# Getting ticker [200]: HAGA4.SA
# Getting ticker [437]: RSUL3.SA
# Getting ticker [437]: RSUL4.SA
# Getting ticker [376]: PPAR3.SA
# Getting ticker [227]: PLAS3.SA
# Getting ticker [171]: MNPR3.SA
# Getting ticker [55]: PTBL3.SA
# Getting ticker [162]: SCAR3.SA
# Getting ticker [366]: MAPT3.SA
# Getting ticker [366]: MAPT4.SA
# Getting ticker [46]: SUZB6.SA
# Getting ticker [46]: SUZB5.SA
# Getting ticker [107]: RAPT3.SA
# Getting ticker [107]: RAPT4.SA
# Getting ticker [50]: TOYB3.SA
# Getting ticker [50]: TOYB4.SA
# Getting ticker [565]: ELPL3.SA
# Getting ticker [565]: ELPL4.SA
# Getting ticker [151]: BSLI3.SA
# Getting ticker [151]: BSLI4.SA
# Getting ticker [60]: CPLE3.SA
# Getting ticker [60]: CPLE5.SA
# Getting ticker [384]: USIM3.SA
# Getting ticker [384]: USIM5.SA
# Getting ticker [89]: WHRL3.SA
# Getting ticker [89]: WHRL4.SA
# Getting ticker [243]: CEPE3.SA
# Getting ticker [243]: CEPE5.SA
# Getting ticker [223]: SBSP3.SA
# Getting ticker [83]: CEBR3.SA
# Getting ticker [83]: CEBR5.SA
# Getting ticker [23]: CYRE3.SA
# Getting ticker [206]: CEEB3.SA
# Getting ticker [206]: CEEB5.SA
# Getting ticker [245]: ENMT3.SA
# Getting ticker [245]: ENMT4.SA
# Getting ticker [407]: SHUL3.SA
# Getting ticker [407]: SHUL4.SA
# Getting ticker [69]: HGTX3.SA
# Getting ticker [370]: CMSA3.SA
# Getting ticker [370]: CMSA4.SA
# Getting ticker [380]: PCAR3.SA
# Getting ticker [380]: PCAR4.SA
# Getting ticker [202]: COCE3.SA
# Getting ticker [202]: COCE5.SA
# Getting ticker [690]: DXTG3.SA
# Getting ticker [690]: DXTG4.SA
# Getting ticker [154]: LTEL3B.SA
# Getting ticker [154]: LTEL5B.SA
# Getting ticker [5]: ENGI3.SA
# Getting ticker [5]: ENGI4.SA
# Getting ticker [360]: PSEG3.SA
# Getting ticker [360]: PSEG4.SA
# Getting ticker [168]: FRRN3B.SA
# Getting ticker [168]: FRRN5B.SA
# Getting ticker [95]: VSPT3.SA
# Getting ticker [95]: VSPT4.SA
# Getting ticker [510]: PQTM3.SA
# Getting ticker [510]: PQTM4.SA
# Getting ticker [234]: ATOM3.SA
# Getting ticker [97]: GNAN3B.SA
# Getting ticker [404]: CGAS3.SA
# Getting ticker [404]: CGAS5.SA
# Getting ticker [385]: GRUC3.SA
# Getting ticker [353]: LIPR3.SA
# Getting ticker [391]: SQRM3.SA
# Getting ticker [371]: GFSA3.SA
# Getting ticker [340]: ETRO3B.SA
# Getting ticker [398]: VLTR3B.SA
# Getting ticker [258]: PBEL3B.SA
# Getting ticker [452]: QVQP3B.SA
# Getting ticker [53]: BRFS3.SA
# Getting ticker [112]: RSID3.SA
# Getting ticker [225]: OPTS3B.SA
# Getting ticker [121]: ECPR3.SA
# Getting ticker [121]: ECPR4.SA
# Getting ticker [656]: BNPA3B.SA
# Getting ticker [339]: OPSE3B.SA
# Getting ticker [235]: ENMA3B.SA
# Getting ticker [235]: ENMA5B.SA
# Getting ticker [405]: CEGR3.SA
# Getting ticker [189]: UPKP3B.SA
# Getting ticker [123]: GPCP3.SA
# Getting ticker [439]: PSSA3.SA
# Getting ticker [346]: ALEF3B.SA
# Getting ticker [237]: CASN3.SA
# Getting ticker [237]: CASN4.SA
# Getting ticker [338]: OPHE3B.SA
# Getting ticker [92]: EMAE3.SA
# Getting ticker [92]: EMAE4.SA
# Getting ticker [80]: TBLE3.SA
# Getting ticker [295]: OPRE3B.SA
# Getting ticker [337]: OPZI3B.SA
# Getting ticker [209]: FTRT3B.SA
# Getting ticker [205]: TLVT3B.SA
# Getting ticker [399]: SPRT3B.SA
# Getting ticker [260]: EKTR3.SA
# Getting ticker [260]: EKTR4.SA
# Getting ticker [191]: CPTP3B.SA
# Getting ticker [216]: NEWT3B.SA
# Getting ticker [188]: SLCT3B.SA
# Getting ticker [96]: TIMP3.SA
# Getting ticker [79]: VIVT3.SA
# Getting ticker [79]: VIVT4.SA
# Getting ticker [228]: MAOR3B.SA
# Getting ticker [228]: MAOR4B.SA
# Getting ticker [640]: BETP3B.SA
# Getting ticker [106]: STBP3.SA
# Getting ticker [106]: STBP4.SA
# Getting ticker [39]: MMXM3.SA
# Getting ticker [310]: MRSA3B.SA
# Getting ticker [310]: MRSA5B.SA
# Getting ticker [307]: OPGM3B.SA
# Getting ticker [170]: KROT3.SA
# Getting ticker [239]: CSRN3.SA
# Getting ticker [239]: CSRN5.SA
# Getting ticker [226]: CELP3.SA
# Getting ticker [226]: CELP5.SA
# Getting ticker [342]: PRPT3B.SA
# Getting ticker [244]: GETI3.SA
# Getting ticker [244]: GETI4.SA
# Getting ticker [251]: GEPA3.SA
# Getting ticker [251]: GEPA4.SA
# Getting ticker [180]: TRPL3.SA
# Getting ticker [180]: TRPL4.SA
# Getting ticker [24]: IDNT3.SA
# Getting ticker [126]: UGPA3.SA
# Getting ticker [379]: MNZC3B.SA
# Getting ticker [249]: DTCY3.SA
# Getting ticker [249]: DTCY4.SA
# Getting ticker [498]: SAPR3.SA
# Getting ticker [498]: SAPR4.SA
# Getting ticker [406]: VDNP3B.SA
# Getting ticker [197]: CPFE3.SA
# Getting ticker [128]: PEAB3.SA
# Getting ticker [128]: PEAB4.SA
# Getting ticker [160]: BRAP3.SA
# Getting ticker [160]: BRAP4.SA
# Getting ticker [94]: IVPR3B.SA
# Getting ticker [94]: IVPR4B.SA
# Getting ticker [61]: CCRO3.SA
# Getting ticker [217]: CANT3B.SA
# Getting ticker [217]: CANT4B.SA
# Getting ticker [694]: CALA3B.SA
# Getting ticker [694]: CALA4B.SA
# Getting ticker [369]: CAIA3B.SA
# Getting ticker [27]: CTAX3.SA
# Getting ticker [27]: CTAX4.SA
# Getting ticker [481]: CABI3B.SA
# Getting ticker [378]: CACO3B.SA
# Getting ticker [250]: CRTE3B.SA
# Getting ticker [250]: CRTE5B.SA
# Getting ticker [283]: PRMN3B.SA
# Getting ticker [716]: CRSC3B.SA
# Getting ticker [133]: BIOM3.SA
# Getting ticker [425]: AELP3.SA
# Getting ticker [40]: TPIS3.SA
# Getting ticker [169]: ITUB3.SA
# Getting ticker [169]: ITUB4.SA
# Getting ticker [181]: ANDG3B.SA
# Getting ticker [181]: ANDG4B.SA
# Getting ticker [330]: CSMG3.SA
# Getting ticker [516]: ECOR3.SA
# Getting ticker [375]: NATU3.SA
# Getting ticker [9]: GOLL4.SA
# Getting ticker [90]: GRND3.SA
# Getting ticker [214]: DASA3.SA
# Getting ticker [84]: RNAR3.SA
# Getting ticker [135]: RENT3.SA
# Getting ticker [12]: ENBR3.SA
# Getting ticker [42]: ARTR3.SA
# Getting ticker [32]: CSAN3.SA
# Getting ticker [35]: LIGT3.SA
# Getting ticker [13]: BRML3.SA
# Getting ticker [230]: TEMP3.SA
# Getting ticker [30]: BRPR3.SA
# Getting ticker [105]: TOTS3.SA
# Getting ticker [2]: EQTL3.SA
# Getting ticker [395]: VLID3.SA
# Getting ticker [52]: AGRO3.SA
# Getting ticker [305]: CARD3.SA
# Getting ticker [415]: LUPA3.SA
# Getting ticker [176]: EMBR3.SA
# Getting ticker [66]: ODPV3.SA
# Getting ticker [158]: CREM3.SA
# Getting ticker [450]: AFLU3.SA
# Getting ticker [450]: AFLU5.SA
# Getting ticker [166]: CCXC3.SA
# Getting ticker [17]: TAEE3.SA
# Getting ticker [17]: TAEE11.SA
# Getting ticker [76]: MDIA3.SA
# Getting ticker [54]: PFRM3.SA
# Getting ticker [465]: VAGR3.SA
# Getting ticker [473]: POSI3.SA
# Getting ticker [114]: LPSB3.SA
# Getting ticker [138]: TCSA3.SA
# Getting ticker [48]: RDNI3.SA
# Getting ticker [56]: PDGR3.SA
# Getting ticker [28]: IGTA3.SA
# Getting ticker [145]: SMTO3.SA
# Getting ticker [20]: EVEN3.SA
# Getting ticker [29]: SANB3.SA
# Getting ticker [29]: SANB4.SA
# Getting ticker [87]: CPRE3.SA
# Getting ticker [58]: PINE3.SA
# Getting ticker [58]: PINE4.SA
# Getting ticker [16]: JBSS3.SA
# Getting ticker [125]: JHSF3.SA
# Getting ticker [152]: FRIO3.SA
# Getting ticker [88]: FHER3.SA
# Getting ticker [150]: CRDE3.SA
# Getting ticker [238]: CEED3.SA
# Getting ticker [238]: CEED4.SA
# Getting ticker [502]: SFSA3.SA
# Getting ticker [502]: SFSA4.SA
# Getting ticker [167]: VIVR3.SA
# Getting ticker [38]: LOGN3.SA
# Getting ticker [309]: PRBC4.SA
# Getting ticker [440]: SLCE3.SA
# Getting ticker [157]: EZTC3.SA
# Getting ticker [18]: MRFG3.SA
# Getting ticker [219]: DAYC4.SA
# Getting ticker [41]: TGMA3.SA
# Getting ticker [161]: MAGG3.SA
# Getting ticker [21]: HBOR3.SA
# Getting ticker [218]: IDVL3.SA
# Getting ticker [218]: IDVL4.SA
# Getting ticker [47]: MRVE3.SA
# Getting ticker [3]: BEEF3.SA
# Getting ticker [355]: ABCB4.SA
# Getting ticker [124]: SGPS3.SA
# Getting ticker [37]: MULT3.SA
# Getting ticker [67]: GSHP3.SA
# Getting ticker [14]: ESTC3.SA
# Getting ticker [101]: CCPR3.SA
# Getting ticker [149]: DTEX3.SA
# Getting ticker [15]: SULA3.SA
# Getting ticker [15]: SULA4.SA
# Getting ticker [155]: TRIS3.SA
# Getting ticker [471]: BBRK3.SA
# Getting ticker [183]: BPAN4.SA
# Getting ticker [165]: ENEV3.SA
# Getting ticker [163]: ALSC3.SA
# Getting ticker [192]: NUTR3.SA
# Getting ticker [19]: OSXB3.SA
# Getting ticker [45]: DIRR3.SA
# Getting ticker [74]: GPAR3.SA
# Getting ticker [59]: HYPE3.SA
# Getting ticker [164]: LLIS3.SA
# Getting ticker [179]: PRML3.SA
# Getting ticker [8]: ALUP3.SA
# Getting ticker [8]: ALUP4.SA
# Getting ticker [203]: BVMF3.SA
# Getting ticker [6]: RNEW3.SA
# Getting ticker [6]: RNEW4.SA
# Getting ticker [72]: TRPN3.SA
# Getting ticker [57]: SWET3.SA
# Getting ticker [426]: CIEL3.SA
# Getting ticker [190]: CTIP3.SA
# Getting ticker [82]: FLRY3.SA
# Getting ticker [259]: MPLU3.SA
# Getting ticker [247]: MILS3.SA
# Getting ticker [4]: JSLG3.SA
# Getting ticker [147]: AMAR3.SA
# Getting ticker [269]: RDTR3.SA
# Getting ticker [336]: TERI3.SA
# Getting ticker [271]: AFLT3.SA
# Getting ticker [78]: PRIO3.SA
# Getting ticker [25]: BRIN3.SA
# Getting ticker [478]: RJCP3.SA
# Getting ticker [85]: SSBR3.SA
# Getting ticker [99]: QGEP3.SA
# Getting ticker [31]: SHOW3.SA
# Getting ticker [34]: MGLU3.SA
# Getting ticker [136]: QUAL3.SA
# Getting ticker [44]: BPHA3.SA
# Getting ticker [111]: TECN3.SA
# Getting ticker [73]: SEDU3.SA
# Getting ticker [508]: HPIA3.SA
# Getting ticker [475]: STKF3.SA
# Getting ticker [212]: BPAC3.SA
# Getting ticker [212]: BPAC5.SA
# Getting ticker [256]: LCAM3.SA
# Getting ticker [290]: VIGR3.SA
# Getting ticker [137]: UCAS3.SA
# Getting ticker [117]: SNSL3.SA
# Getting ticker [130]: BSEV3.SA
# Getting ticker [600]: NRTQ3.SA
# Getting ticker [142]: LINX3.SA
# Getting ticker [665]: SMLE3.SA
# Getting ticker [172]: BBSE3.SA
# Getting ticker [102]: CABB3.SA
# Getting ticker [421]: ALTS3.SA
# Getting ticker [421]: ALTS11.SA
# Getting ticker [129]: SEER3.SA
# Getting ticker [196]: ANIM3.SA
# Getting ticker [185]: ABEV3.SA
# Getting ticker [563]: QUSW3.SA
# Getting ticker [466]: CVCB3.SA
# Getting ticker [485]: RUMO3.SA
# Getting ticker [497]: RLOG3.SA
# Getting ticker [207]: OGSA3.SA
# Getting ticker [280]: OFSA3.SA
# Getting ticker [559]: MEAL3.SA
# Getting ticker [279]: PARC3.SA
# Getting ticker [537]: MSRO3.SA
# Getting ticker [438]: HCBR3.SA
# Getting ticker [331]: PRCA3.SA
# Getting ticker [753]: NTCO3.SA
# Getting ticker [744]: VIVA3.SA

# %%
# Generate the dataset with the historical prices for all the tickers.
stock_prices = []
tickers_with_prices = []
for ticker, historical_data in company_stock_prices.items():
    if "prices" in historical_data and len(historical_data["prices"]) > 0:
        tickers_with_prices.append(ticker)
        for stock_price in historical_data["prices"]:
            data = stock_price.copy()
            data["ticker"] = ticker
            data["type"] = "EQUITY"
            stock_prices.append(data)
                        
stock_prices_df = pd.DataFrame(stock_prices)
# Convert the 'formatted_date' column type from string to datetime
stock_prices_df['formatted_date'] =  pd.to_datetime(stock_prices_df['formatted_date'], format='%Y-%m-%d')

# %%
print(f"We have {len(tickers_with_prices)} with historic stock prices")
# Out:
# We have 320 with historic stock prices

# %%
stock_prices_df.head(10)
# Out:
#         date     high      low     open    close    volume  adjclose  \
# 0  946900800  2.85333  2.73333  2.80000  2.73333  514800.0  1.549851
# 1  946987200  2.74000  2.60333  2.73333  2.60333  314100.0  1.476138
# 2  947073600  2.63333  2.50667  2.60000  2.63000  478800.0  1.491260
# 3  947160000  2.66667  2.60000  2.63000  2.66667  205200.0  1.512054
# 4  947246400  2.66667  2.60667  2.66667  2.60667  394200.0  1.478032
# 5  947505600  2.75333  2.66667  2.73000  2.75000  549000.0  1.559303
# 6  947592000  2.85333  2.67667  2.76667  2.71333  642600.0  1.538510
# 7  947678400  2.76667  2.68333  2.73333  2.75000  584100.0  1.559303
# 8  947764800  2.83333  2.70333  2.80000  2.70333  551700.0  1.532841
# 9  947851200  2.76667  2.70000  2.73333  2.70000  248400.0  1.530952
#
#   formatted_date ticker    type  amount  data
# 0     2000-01-03  BBAS3  EQUITY     NaN   NaN
# 1     2000-01-04  BBAS3  EQUITY     NaN   NaN
# 2     2000-01-05  BBAS3  EQUITY     NaN   NaN
# 3     2000-01-06  BBAS3  EQUITY     NaN   NaN
# 4     2000-01-07  BBAS3  EQUITY     NaN   NaN
# 5     2000-01-10  BBAS3  EQUITY     NaN   NaN
# 6     2000-01-11  BBAS3  EQUITY     NaN   NaN
# 7     2000-01-12  BBAS3  EQUITY     NaN   NaN
# 8     2000-01-13  BBAS3  EQUITY     NaN   NaN
# 9     2000-01-14  BBAS3  EQUITY     NaN   NaN

# %%
# Save the dataset as a CSV file
stock_prices_df.to_csv('stock_prices.csv')

# %%
# Generate the dataset with the historical events for all the tickers.
ticker_events = []
for ticker, historical_data in company_stock_prices.items():
    if "eventsData" in historical_data:        
        if "dividends" in historical_data["eventsData"] and len(historical_data["eventsData"]["dividends"]) > 0:
            for date, dividend in historical_data["eventsData"]["dividends"].items():
                data = dividend.copy()
                data["type"] = "dividend"
                data["ticker"] = ticker
                ticker_events.append(data)

        if "splits" in historical_data["eventsData"] and len(historical_data["eventsData"]["splits"]) > 0:
            for date, split in historical_data["eventsData"]["splits"].items():
                data = split.copy()
                data["type"] = "split"                
                data["ticker"] = ticker
                ticker_events.append(data)

ticker_events_df = pd.DataFrame(ticker_events)
# Convert the 'formatted_date' column type from string to datetime
ticker_events_df['formatted_date'] =  pd.to_datetime(ticker_events_df['formatted_date'], format='%Y-%m-%d')

# %%
ticker_events_df.head(10)
# Out:
#      amount        date formatted_date      type ticker  numerator  \
# 0  0.285821  1347454800     2012-09-12  dividend  BBAS3        NaN
# 1  0.156962  1305896400     2011-05-20  dividend  BBAS3        NaN
# 2  0.125885  1321617600     2011-11-18  dividend  BBAS3        NaN
# 3  0.126652  1473771600     2016-09-13  dividend  BBAS3        NaN
# 4  0.090568  1457010000     2016-03-03  dividend  BBAS3        NaN
# 5  0.297177  1355400000     2012-12-13  dividend  BBAS3        NaN
# 6  0.141039  1440421200     2015-08-24  dividend  BBAS3        NaN
# 7  0.446155  1566478800     2019-08-22  dividend  BBAS3        NaN
# 8  0.451138  1432299600     2015-05-22  dividend  BBAS3        NaN
# 9  0.137755  1465909200     2016-06-14  dividend  BBAS3        NaN
#
#    denominator splitRatio
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# 5          NaN        NaN
# 6          NaN        NaN
# 7          NaN        NaN
# 8          NaN        NaN
# 9          NaN        NaN

# %%
# Save the dataset as a CSV file
ticker_events_df.to_csv('ticker_events.csv')

# %%
# Generate the dataset with the ticker details.
ticker_details = []
for ticker, historical_data in company_stock_prices.items():
    ticker_data = {
        "ticker": ticker        
    }
    
    if "firstTradeDate" in historical_data: 
        ticker_data["first_trade_date"] = historical_data["firstTradeDate"]["date"]
        ticker_data["first_trade_formatted_date"] = pd.to_datetime(
            historical_data["firstTradeDate"]["formatted_date"], 
            format='%Y-%m-%d')
        
    if "currency" in historical_data:
        ticker_data["currency"] = historical_data["currency"]

    if "instrumentType" in historical_data:
        ticker_data["instrument_type"] = historical_data["instrumentType"]

    if "timeZone" in historical_data:
        ticker_data["time_zone_gmt_offset"] = historical_data["timeZone"]["gmtOffset"]
    
    ticker_details.append(ticker_data)

ticker_details_df = pd.DataFrame(ticker_details)

# %%
ticker_details_df.head(10)
# Out:
#   ticker  first_trade_date first_trade_formatted_date currency  \
# 0  BBAS3      9.468999e+08                 2000-01-03      BRL
# 1  BGIP3      1.535720e+09                 2018-08-31      BRL
# 2  BGIP4      1.199274e+09                 2008-01-02      BRL
# 3  BEES3      9.468999e+08                 2000-01-03      BRL
# 4  BEES4      1.211892e+09                 2008-05-27      BRL
# 5  BPAR3      1.556196e+09                 2019-04-25      BRL
# 6  BRSR3      9.468999e+08                 2000-01-03      BRL
# 7  BRSR5      1.534424e+09                 2018-08-16      BRL
# 8  BNBR3      9.469863e+08                 2000-01-04      BRL
# 9  BMIN3      1.530536e+09                 2018-07-02      BRL
#
#   instrument_type  time_zone_gmt_offset
# 0          EQUITY               -7200.0
# 1          EQUITY               -7200.0
# 2          EQUITY               -7200.0
# 3          EQUITY               -7200.0
# 4          EQUITY               -7200.0
# 5          EQUITY               -7200.0
# 6          EQUITY               -7200.0
# 7          EQUITY               -7200.0
# 8          EQUITY               -7200.0
# 9          EQUITY               -7200.0

# %%
# Save the dataset as a CSV file
ticker_details_df.to_csv('ticker_details.csv')

# %%
print(f"Total data points: {stock_prices_df.count()}")
# Out:
# Total data points: date              924037
# high              859704
# low               859704
# open              859704
# close             859704
# volume            859704
# adjclose          859704
# formatted_date    924037
# ticker            924037
# amount                 5
# type                   5
# data                   5
# dtype: int64

# %%
stock_prices_aggr_df = stock_prices_df.groupby(["ticker"]).count()
stock_prices_aggr_df.mean()
# Out:
# date              2887.615625
# high              2686.575000
# low               2686.575000
# open              2686.575000
# close             2686.575000
# volume            2686.575000
# adjclose          2686.575000
# formatted_date    2887.615625
# amount               0.015625
# type                 0.015625
# data                 0.015625
# dtype: float64

# %% [markdown]
# # Bovespa Index
#
# We need to get the history index price of the index of reference of Bovespa, IBOV.
#
# This index is accessible through the ticker: __^BVSP__.
#
# We will save the result in the file: __ibov.csv__.

# %%
finance = YahooFinancials(f"^BVSP")
ibov_data = finance.get_historical_price_data('2000-01-01', '2020-01-03', 'daily')

# %%
ibov_data
# Out:
# {'^BVSP': {'eventsData': {},
#   'firstTradeDate': {'formatted_date': '1993-04-27', 'date': 735914700},
#   'currency': 'BRL',
#   'instrumentType': 'INDEX',
#   'timeZone': {'gmtOffset': -7200},
#   'prices': [{'date': 946900800,
#     'high': 17408.0,
#     'low': 16719.0,
#     'open': 17098.0,
#     'close': 16930.0,
#     'volume': 0,
#     'adjclose': 16930.0,
#     'formatted_date': '2000-01-03'},
#    {'date': 946987200,
#     'high': 16908.0,
#     'low': 15851.0,
#     'open': 16908.0,
#     'close': 15851.0,
#     'volume': 0,
#     'adjclose': 15851.0,
#     'formatted_date': '2000-01-04'},
#    {'date': 947073600,
#     'high': 16302.0,
#     'low': 15350.0,
#     'open': 15871.0,
#     'close': 16245.0,
#     'volume': 0,
#     'adjclose': 16245.0,
#     'formatted_date': '2000-01-05'},
#    {'date': 947160000,
#     'high': 16499.0,
#     'low': 15977.0,
#     'open': 16237.0,
#     'close': 16107.0,
#     'volume': 0,
#     'adjclose': 16107.0,
#     'formatted_date': '2000-01-06'},
#    {'date': 947246400,
#     'high': 16449.0,
#     'low': 16125.0,
#     'open': 16125.0,
#     'close': 16309.0,
#     'volume': 0,
#     'adjclose': 16309.0,
#     'formatted_date': '2000-01-07'},
#    {'date': 947505600,
#     'high': 17057.0,
#     'low': 16325.0,
#     'open': 16325.0,
#     'close': 17022.0,
#     'volume': 0,
#     'adjclose': 17022.0,
#     'formatted_date': '2000-01-10'},
#    {'date': 947592000,
#     'high': 17197.0,
#     'low': 16573.0,
#     'open': 17045.0,
#     'close': 16573.0,
#     'volume': 0,
#     'adjclose': 16573.0,
#     'formatted_date': '2000-01-11'},
#    {'date': 947678400,
#     'high': 16724.0,
#     'low': 16331.0,
#     'open': 16574.0,
#     'close': 16617.0,
#     'volume': 0,
#     'adjclose': 16617.0,
#     'formatted_date': '2000-01-12'},
#    {'date': 947764800,
#     'high': 17715.0,
#     'low': 16663.0,
#     'open': 16663.0,
#     'close': 17298.0,
#     'volume': 0,
#     'adjclose': 17298.0,
#     'formatted_date': '2000-01-13'},
#    {'date': 947851200,
#     'high': 17800.0,
#     'low': 17306.0,
#     'open': 17306.0,
#     'close': 17658.0,
#     'volume': 0,
#     'adjclose': 17658.0,
#     'formatted_date': '2000-01-14'},
#    {'date': 948110400,
#     'high': 18099.0,
#     'low': 17678.0,
#     'open': 17678.0,
#     'close': 18053.0,
#     'volume': 0,
#     'adjclose': 18053.0,
#     'formatted_date': '2000-01-17'},
#    {'date': 948196800,
#     'high': 18062.0,
#     'low': 17625.0,
#     'open': 18062.0,
#     'close': 17903.0,
#     'volume': 0,
#     'adjclose': 17903.0,
#     'formatted_date': '2000-01-18'},
#    {'date': 948283200,
#     'high': 18075.0,
#     'low': 17470.0,
#     'open': 17905.0,
#     'close': 17470.0,
#     'volume': 0,
#     'adjclose': 17470.0,
#     'formatted_date': '2000-01-19'},
#    {'date': 948369600,
#     'high': 17622.0,
#     'low': 17029.0,
#     'open': 17487.0,
#     'close': 17177.0,
#     'volume': 0,
#     'adjclose': 17177.0,
#     'formatted_date': '2000-01-20'},
#    {'date': 948456000,
#     'high': 17372.0,
#     'low': 16901.0,
#     'open': 17188.0,
#     'close': 17034.0,
#     'volume': 0,
#     'adjclose': 17034.0,
#     'formatted_date': '2000-01-21'},
#    {'date': 948715200,
#     'high': 17263.0,
#     'low': 16972.0,
#     'open': 17049.0,
#     'close': 16972.0,
#     'volume': 0,
#     'adjclose': 16972.0,
#     'formatted_date': '2000-01-24'},
#    {'date': 948801600,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-01-25'},
#    {'date': 948888000,
#     'high': 17105.0,
#     'low': 16727.0,
#     'open': 16972.0,
#     'close': 17105.0,
#     'volume': 0,
#     'adjclose': 17105.0,
#     'formatted_date': '2000-01-26'},
#    {'date': 948974400,
#     'high': 17422.0,
#     'low': 17081.0,
#     'open': 17114.0,
#     'close': 17081.0,
#     'volume': 0,
#     'adjclose': 17081.0,
#     'formatted_date': '2000-01-27'},
#    {'date': 949060800,
#     'high': 17252.0,
#     'low': 16547.0,
#     'open': 17150.0,
#     'close': 16734.0,
#     'volume': 0,
#     'adjclose': 16734.0,
#     'formatted_date': '2000-01-28'},
#    {'date': 949320000,
#     'high': 16749.0,
#     'low': 16167.0,
#     'open': 16744.0,
#     'close': 16388.0,
#     'volume': 0,
#     'adjclose': 16388.0,
#     'formatted_date': '2000-01-31'},
#    {'date': 949406400,
#     'high': 16675.0,
#     'low': 16389.0,
#     'open': 16389.0,
#     'close': 16522.0,
#     'volume': 0,
#     'adjclose': 16522.0,
#     'formatted_date': '2000-02-01'},
#    {'date': 949492800,
#     'high': 16875.0,
#     'low': 16546.0,
#     'open': 16546.0,
#     'close': 16868.0,
#     'volume': 0,
#     'adjclose': 16868.0,
#     'formatted_date': '2000-02-02'},
#    {'date': 949579200,
#     'high': 17457.0,
#     'low': 16892.0,
#     'open': 16892.0,
#     'close': 17457.0,
#     'volume': 0,
#     'adjclose': 17457.0,
#     'formatted_date': '2000-02-03'},
#    {'date': 949665600,
#     'high': 17962.0,
#     'low': 17471.0,
#     'open': 17471.0,
#     'close': 17932.0,
#     'volume': 0,
#     'adjclose': 17932.0,
#     'formatted_date': '2000-02-04'},
#    {'date': 949924800,
#     'high': 18126.0,
#     'low': 17746.0,
#     'open': 17937.0,
#     'close': 18126.0,
#     'volume': 0,
#     'adjclose': 18126.0,
#     'formatted_date': '2000-02-07'},
#    {'date': 950011200,
#     'high': 18729.0,
#     'low': 18249.0,
#     'open': 18249.0,
#     'close': 18686.0,
#     'volume': 0,
#     'adjclose': 18686.0,
#     'formatted_date': '2000-02-08'},
#    {'date': 950097600,
#     'high': 18886.0,
#     'low': 18224.0,
#     'open': 18759.0,
#     'close': 18361.0,
#     'volume': 0,
#     'adjclose': 18361.0,
#     'formatted_date': '2000-02-09'},
#    {'date': 950184000,
#     'high': 18672.0,
#     'low': 18155.0,
#     'open': 18367.0,
#     'close': 18604.0,
#     'volume': 0,
#     'adjclose': 18604.0,
#     'formatted_date': '2000-02-10'},
#    {'date': 950270400,
#     'high': 18775.0,
#     'low': 18027.0,
#     'open': 18635.0,
#     'close': 18083.0,
#     'volume': 0,
#     'adjclose': 18083.0,
#     'formatted_date': '2000-02-11'},
#    {'date': 950529600,
#     'high': 18264.0,
#     'low': 17746.0,
#     'open': 18083.0,
#     'close': 17819.0,
#     'volume': 0,
#     'adjclose': 17819.0,
#     'formatted_date': '2000-02-14'},
#    {'date': 950616000,
#     'high': 17932.0,
#     'low': 17451.0,
#     'open': 17818.0,
#     'close': 17921.0,
#     'volume': 0,
#     'adjclose': 17921.0,
#     'formatted_date': '2000-02-15'},
#    {'date': 950702400,
#     'high': 18247.0,
#     'low': 17743.0,
#     'open': 17921.0,
#     'close': 18112.0,
#     'volume': 0,
#     'adjclose': 18112.0,
#     'formatted_date': '2000-02-16'},
#    {'date': 950788800,
#     'high': 18297.0,
#     'low': 17979.0,
#     'open': 18116.0,
#     'close': 17979.0,
#     'volume': 0,
#     'adjclose': 17979.0,
#     'formatted_date': '2000-02-17'},
#    {'date': 950875200,
#     'high': 18008.0,
#     'low': 17489.0,
#     'open': 17979.0,
#     'close': 17625.0,
#     'volume': 0,
#     'adjclose': 17625.0,
#     'formatted_date': '2000-02-18'},
#    {'date': 951134400,
#     'high': 17887.0,
#     'low': 17364.0,
#     'open': 17626.0,
#     'close': 17700.0,
#     'volume': 0,
#     'adjclose': 17700.0,
#     'formatted_date': '2000-02-21'},
#    {'date': 951220800,
#     'high': 17913.0,
#     'low': 17466.0,
#     'open': 17698.0,
#     'close': 17489.0,
#     'volume': 0,
#     'adjclose': 17489.0,
#     'formatted_date': '2000-02-22'},
#    {'date': 951307200,
#     'high': 17855.0,
#     'low': 17479.0,
#     'open': 17489.0,
#     'close': 17833.0,
#     'volume': 0,
#     'adjclose': 17833.0,
#     'formatted_date': '2000-02-23'},
#    {'date': 951393600,
#     'high': 18119.0,
#     'low': 17706.0,
#     'open': 17846.0,
#     'close': 17776.0,
#     'volume': 0,
#     'adjclose': 17776.0,
#     'formatted_date': '2000-02-24'},
#    {'date': 951480000,
#     'high': 17988.0,
#     'low': 17758.0,
#     'open': 17784.0,
#     'close': 17787.0,
#     'volume': 0,
#     'adjclose': 17787.0,
#     'formatted_date': '2000-02-25'},
#    {'date': 951742800,
#     'high': 17787.0,
#     'low': 17383.0,
#     'open': 17787.0,
#     'close': 17543.0,
#     'volume': 0,
#     'adjclose': 17543.0,
#     'formatted_date': '2000-02-28'},
#    {'date': 951829200,
#     'high': 17818.0,
#     'low': 17545.0,
#     'open': 17545.0,
#     'close': 17660.0,
#     'volume': 0,
#     'adjclose': 17660.0,
#     'formatted_date': '2000-02-29'},
#    {'date': 951915600,
#     'high': 17953.0,
#     'low': 17655.0,
#     'open': 17668.0,
#     'close': 17953.0,
#     'volume': 0,
#     'adjclose': 17953.0,
#     'formatted_date': '2000-03-01'},
#    {'date': 952002000,
#     'high': 18154.0,
#     'low': 17809.0,
#     'open': 17966.0,
#     'close': 18016.0,
#     'volume': 0,
#     'adjclose': 18016.0,
#     'formatted_date': '2000-03-02'},
#    {'date': 952088400,
#     'high': 18632.0,
#     'low': 18016.0,
#     'open': 18016.0,
#     'close': 18632.0,
#     'volume': 0,
#     'adjclose': 18632.0,
#     'formatted_date': '2000-03-03'},
#    {'date': 952347600,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-03-06'},
#    {'date': 952434000,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-03-07'},
#    {'date': 952520400,
#     'high': 18617.0,
#     'low': 18184.0,
#     'open': 18617.0,
#     'close': 18283.0,
#     'volume': 0,
#     'adjclose': 18283.0,
#     'formatted_date': '2000-03-08'},
#    {'date': 952606800,
#     'high': 18650.0,
#     'low': 18285.0,
#     'open': 18285.0,
#     'close': 18650.0,
#     'volume': 0,
#     'adjclose': 18650.0,
#     'formatted_date': '2000-03-09'},
#    {'date': 952693200,
#     'high': 18720.0,
#     'low': 18233.0,
#     'open': 18650.0,
#     'close': 18280.0,
#     'volume': 0,
#     'adjclose': 18280.0,
#     'formatted_date': '2000-03-10'},
#    {'date': 952952400,
#     'high': 18279.0,
#     'low': 17506.0,
#     'open': 18279.0,
#     'close': 17595.0,
#     'volume': 0,
#     'adjclose': 17595.0,
#     'formatted_date': '2000-03-13'},
#    {'date': 953038800,
#     'high': 17941.0,
#     'low': 17222.0,
#     'open': 17595.0,
#     'close': 17222.0,
#     'volume': 0,
#     'adjclose': 17222.0,
#     'formatted_date': '2000-03-14'},
#    {'date': 953125200,
#     'high': 17469.0,
#     'low': 16922.0,
#     'open': 17229.0,
#     'close': 17382.0,
#     'volume': 0,
#     'adjclose': 17382.0,
#     'formatted_date': '2000-03-15'},
#    {'date': 953211600,
#     'high': 17661.0,
#     'low': 17397.0,
#     'open': 17397.0,
#     'close': 17642.0,
#     'volume': 0,
#     'adjclose': 17642.0,
#     'formatted_date': '2000-03-16'},
#    {'date': 953298000,
#     'high': 17733.0,
#     'low': 17470.0,
#     'open': 17654.0,
#     'close': 17511.0,
#     'volume': 0,
#     'adjclose': 17511.0,
#     'formatted_date': '2000-03-17'},
#    {'date': 953557200,
#     'high': 17733.0,
#     'low': 17435.0,
#     'open': 17511.0,
#     'close': 17526.0,
#     'volume': 0,
#     'adjclose': 17526.0,
#     'formatted_date': '2000-03-20'},
#    {'date': 953643600,
#     'high': 18343.0,
#     'low': 17510.0,
#     'open': 17528.0,
#     'close': 18343.0,
#     'volume': 0,
#     'adjclose': 18343.0,
#     'formatted_date': '2000-03-21'},
#    {'date': 953730000,
#     'high': 18860.0,
#     'low': 18314.0,
#     'open': 18346.0,
#     'close': 18314.0,
#     'volume': 0,
#     'adjclose': 18314.0,
#     'formatted_date': '2000-03-22'},
#    {'date': 953816400,
#     'high': 18644.0,
#     'low': 18183.0,
#     'open': 18314.0,
#     'close': 18331.0,
#     'volume': 0,
#     'adjclose': 18331.0,
#     'formatted_date': '2000-03-23'},
#    {'date': 953902800,
#     'high': 18692.0,
#     'low': 18332.0,
#     'open': 18332.0,
#     'close': 18675.0,
#     'volume': 0,
#     'adjclose': 18675.0,
#     'formatted_date': '2000-03-24'},
#    {'date': 954162000,
#     'high': 19047.0,
#     'low': 18533.0,
#     'open': 18675.0,
#     'close': 18951.0,
#     'volume': 0,
#     'adjclose': 18951.0,
#     'formatted_date': '2000-03-27'},
#    {'date': 954248400,
#     'high': 18960.0,
#     'low': 18335.0,
#     'open': 18952.0,
#     'close': 18338.0,
#     'volume': 0,
#     'adjclose': 18338.0,
#     'formatted_date': '2000-03-28'},
#    {'date': 954334800,
#     'high': 18575.0,
#     'low': 17973.0,
#     'open': 18339.0,
#     'close': 18053.0,
#     'volume': 0,
#     'adjclose': 18053.0,
#     'formatted_date': '2000-03-29'},
#    {'date': 954421200,
#     'high': 18053.0,
#     'low': 17455.0,
#     'open': 18053.0,
#     'close': 17647.0,
#     'volume': 0,
#     'adjclose': 17647.0,
#     'formatted_date': '2000-03-30'},
#    {'date': 954507600,
#     'high': 17950.0,
#     'low': 17560.0,
#     'open': 17660.0,
#     'close': 17820.0,
#     'volume': 0,
#     'adjclose': 17820.0,
#     'formatted_date': '2000-03-31'},
#    {'date': 954766800,
#     'high': 17826.0,
#     'low': 17173.0,
#     'open': 17826.0,
#     'close': 17245.0,
#     'volume': 0,
#     'adjclose': 17245.0,
#     'formatted_date': '2000-04-03'},
#    {'date': 954853200,
#     'high': 17450.0,
#     'low': 16095.0,
#     'open': 17253.0,
#     'close': 16758.0,
#     'volume': 0,
#     'adjclose': 16758.0,
#     'formatted_date': '2000-04-04'},
#    {'date': 954939600,
#     'high': 17043.0,
#     'low': 16230.0,
#     'open': 16762.0,
#     'close': 16714.0,
#     'volume': 0,
#     'adjclose': 16714.0,
#     'formatted_date': '2000-04-05'},
#    {'date': 955026000,
#     'high': 17152.0,
#     'low': 16719.0,
#     'open': 16719.0,
#     'close': 17146.0,
#     'volume': 0,
#     'adjclose': 17146.0,
#     'formatted_date': '2000-04-06'},
#    {'date': 955112400,
#     'high': 17514.0,
#     'low': 17150.0,
#     'open': 17150.0,
#     'close': 17514.0,
#     'volume': 0,
#     'adjclose': 17514.0,
#     'formatted_date': '2000-04-07'},
#    {'date': 955371600,
#     'high': 17572.0,
#     'low': 16782.0,
#     'open': 17519.0,
#     'close': 16783.0,
#     'volume': 0,
#     'adjclose': 16783.0,
#     'formatted_date': '2000-04-10'},
#    {'date': 955458000,
#     'high': 16867.0,
#     'low': 16309.0,
#     'open': 16787.0,
#     'close': 16539.0,
#     'volume': 0,
#     'adjclose': 16539.0,
#     'formatted_date': '2000-04-11'},
#    {'date': 955544400,
#     'high': 16785.0,
#     'low': 16311.0,
#     'open': 16542.0,
#     'close': 16323.0,
#     'volume': 0,
#     'adjclose': 16323.0,
#     'formatted_date': '2000-04-12'},
#    {'date': 955630800,
#     'high': 16605.0,
#     'low': 15501.0,
#     'open': 16325.0,
#     'close': 15501.0,
#     'volume': 0,
#     'adjclose': 15501.0,
#     'formatted_date': '2000-04-13'},
#    {'date': 955717200,
#     'high': 15501.0,
#     'low': 14596.0,
#     'open': 15501.0,
#     'close': 14794.0,
#     'volume': 0,
#     'adjclose': 14794.0,
#     'formatted_date': '2000-04-14'},
#    {'date': 955976400,
#     'high': 14821.0,
#     'low': 14029.0,
#     'open': 14761.0,
#     'close': 14816.0,
#     'volume': 0,
#     'adjclose': 14816.0,
#     'formatted_date': '2000-04-17'},
#    {'date': 956062800,
#     'high': 15469.0,
#     'low': 14767.0,
#     'open': 14817.0,
#     'close': 15408.0,
#     'volume': 0,
#     'adjclose': 15408.0,
#     'formatted_date': '2000-04-18'},
#    {'date': 956149200,
#     'high': 15536.0,
#     'low': 14850.0,
#     'open': 15438.0,
#     'close': 14926.0,
#     'volume': 0,
#     'adjclose': 14926.0,
#     'formatted_date': '2000-04-19'},
#    {'date': 956235600,
#     'high': 15204.0,
#     'low': 14938.0,
#     'open': 14938.0,
#     'close': 15203.0,
#     'volume': 0,
#     'adjclose': 15203.0,
#     'formatted_date': '2000-04-20'},
#    {'date': 956322000,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-04-21'},
#    {'date': 956581200,
#     'high': 15225.0,
#     'low': 14625.0,
#     'open': 15204.0,
#     'close': 14794.0,
#     'volume': 0,
#     'adjclose': 14794.0,
#     'formatted_date': '2000-04-24'},
#    {'date': 956667600,
#     'high': 15403.0,
#     'low': 14798.0,
#     'open': 14798.0,
#     'close': 15401.0,
#     'volume': 0,
#     'adjclose': 15401.0,
#     'formatted_date': '2000-04-25'},
#    {'date': 956754000,
#     'high': 15517.0,
#     'low': 15268.0,
#     'open': 15401.0,
#     'close': 15446.0,
#     'volume': 0,
#     'adjclose': 15446.0,
#     'formatted_date': '2000-04-26'},
#    {'date': 956840400,
#     'high': 15487.0,
#     'low': 14835.0,
#     'open': 15446.0,
#     'close': 15440.0,
#     'volume': 0,
#     'adjclose': 15440.0,
#     'formatted_date': '2000-04-27'},
#    {'date': 956926800,
#     'high': 15907.0,
#     'low': 15450.0,
#     'open': 15450.0,
#     'close': 15538.0,
#     'volume': 0,
#     'adjclose': 15538.0,
#     'formatted_date': '2000-04-28'},
#    {'date': 957186000,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-05-01'},
#    {'date': 957272400,
#     'high': 15944.0,
#     'low': 15523.0,
#     'open': 15596.0,
#     'close': 15524.0,
#     'volume': 0,
#     'adjclose': 15524.0,
#     'formatted_date': '2000-05-02'},
#    {'date': 957358800,
#     'high': 15525.0,
#     'low': 14980.0,
#     'open': 15525.0,
#     'close': 15109.0,
#     'volume': 0,
#     'adjclose': 15109.0,
#     'formatted_date': '2000-05-03'},
#    {'date': 957445200,
#     'high': 15144.0,
#     'low': 14873.0,
#     'open': 15111.0,
#     'close': 14970.0,
#     'volume': 0,
#     'adjclose': 14970.0,
#     'formatted_date': '2000-05-04'},
#    {'date': 957531600,
#     'high': 15218.0,
#     'low': 14811.0,
#     'open': 14967.0,
#     'close': 15218.0,
#     'volume': 0,
#     'adjclose': 15218.0,
#     'formatted_date': '2000-05-05'},
#    {'date': 957790800,
#     'high': 15223.0,
#     'low': 14867.0,
#     'open': 15220.0,
#     'close': 14891.0,
#     'volume': 0,
#     'adjclose': 14891.0,
#     'formatted_date': '2000-05-08'},
#    {'date': 957877200,
#     'high': 15041.0,
#     'low': 14412.0,
#     'open': 14897.0,
#     'close': 14582.0,
#     'volume': 0,
#     'adjclose': 14582.0,
#     'formatted_date': '2000-05-09'},
#    {'date': 957963600,
#     'high': 14586.0,
#     'low': 14238.0,
#     'open': 14570.0,
#     'close': 14434.0,
#     'volume': 0,
#     'adjclose': 14434.0,
#     'formatted_date': '2000-05-10'},
#    {'date': 958050000,
#     'high': 14723.0,
#     'low': 14398.0,
#     'open': 14447.0,
#     'close': 14499.0,
#     'volume': 0,
#     'adjclose': 14499.0,
#     'formatted_date': '2000-05-11'},
#    {'date': 958136400,
#     'high': 14638.0,
#     'low': 14350.0,
#     'open': 14496.0,
#     'close': 14459.0,
#     'volume': 0,
#     'adjclose': 14459.0,
#     'formatted_date': '2000-05-12'},
#    {'date': 958395600,
#     'high': 15070.0,
#     'low': 14397.0,
#     'open': 14469.0,
#     'close': 15056.0,
#     'volume': 0,
#     'adjclose': 15056.0,
#     'formatted_date': '2000-05-15'},
#    {'date': 958482000,
#     'high': 15445.0,
#     'low': 15074.0,
#     'open': 15074.0,
#     'close': 15360.0,
#     'volume': 0,
#     'adjclose': 15360.0,
#     'formatted_date': '2000-05-16'},
#    {'date': 958568400,
#     'high': 15361.0,
#     'low': 14856.0,
#     'open': 15361.0,
#     'close': 14871.0,
#     'volume': 0,
#     'adjclose': 14871.0,
#     'formatted_date': '2000-05-17'},
#    {'date': 958654800,
#     'high': 14973.0,
#     'low': 14620.0,
#     'open': 14876.0,
#     'close': 14627.0,
#     'volume': 0,
#     'adjclose': 14627.0,
#     'formatted_date': '2000-05-18'},
#    {'date': 958741200,
#     'high': 14619.0,
#     'low': 13920.0,
#     'open': 14594.0,
#     'close': 14327.0,
#     'volume': 0,
#     'adjclose': 14327.0,
#     'formatted_date': '2000-05-19'},
#    {'date': 959000400,
#     'high': 14369.0,
#     'low': 13583.0,
#     'open': 14330.0,
#     'close': 13891.0,
#     'volume': 0,
#     'adjclose': 13891.0,
#     'formatted_date': '2000-05-22'},
#    {'date': 959086800,
#     'high': 14145.0,
#     'low': 13583.0,
#     'open': 13891.0,
#     'close': 13587.0,
#     'volume': 0,
#     'adjclose': 13587.0,
#     'formatted_date': '2000-05-23'},
#    {'date': 959173200,
#     'high': 14197.0,
#     'low': 13556.0,
#     'open': 13592.0,
#     'close': 14166.0,
#     'volume': 0,
#     'adjclose': 14166.0,
#     'formatted_date': '2000-05-24'},
#    {'date': 959259600,
#     'high': 14499.0,
#     'low': 14027.0,
#     'open': 14187.0,
#     'close': 14186.0,
#     'volume': 0,
#     'adjclose': 14186.0,
#     'formatted_date': '2000-05-25'},
#    {'date': 959346000,
#     'high': 14549.0,
#     'low': 14172.0,
#     'open': 14204.0,
#     'close': 14542.0,
#     'volume': 0,
#     'adjclose': 14542.0,
#     'formatted_date': '2000-05-26'},
#    {'date': 959605200,
#     'high': 14858.0,
#     'low': 14541.0,
#     'open': 14541.0,
#     'close': 14773.0,
#     'volume': 0,
#     'adjclose': 14773.0,
#     'formatted_date': '2000-05-29'},
#    {'date': 959691600,
#     'high': 15308.0,
#     'low': 14815.0,
#     'open': 14815.0,
#     'close': 15249.0,
#     'volume': 0,
#     'adjclose': 15249.0,
#     'formatted_date': '2000-05-30'},
#    {'date': 959778000,
#     'high': 15328.0,
#     'low': 14931.0,
#     'open': 15251.0,
#     'close': 14957.0,
#     'volume': 0,
#     'adjclose': 14957.0,
#     'formatted_date': '2000-05-31'},
#    {'date': 959864400,
#     'high': 15473.0,
#     'low': 14967.0,
#     'open': 14967.0,
#     'close': 15450.0,
#     'volume': 0,
#     'adjclose': 15450.0,
#     'formatted_date': '2000-06-01'},
#    {'date': 959950800,
#     'high': 16261.0,
#     'low': 15518.0,
#     'open': 15518.0,
#     'close': 16222.0,
#     'volume': 0,
#     'adjclose': 16222.0,
#     'formatted_date': '2000-06-02'},
#    {'date': 960210000,
#     'high': 16312.0,
#     'low': 15975.0,
#     'open': 16222.0,
#     'close': 16023.0,
#     'volume': 0,
#     'adjclose': 16023.0,
#     'formatted_date': '2000-06-05'},
#    {'date': 960296400,
#     'high': 16173.0,
#     'low': 15827.0,
#     'open': 16018.0,
#     'close': 15947.0,
#     'volume': 0,
#     'adjclose': 15947.0,
#     'formatted_date': '2000-06-06'},
#    {'date': 960382800,
#     'high': 16278.0,
#     'low': 15709.0,
#     'open': 15955.0,
#     'close': 16272.0,
#     'volume': 0,
#     'adjclose': 16272.0,
#     'formatted_date': '2000-06-07'},
#    {'date': 960469200,
#     'high': 16640.0,
#     'low': 16227.0,
#     'open': 16286.0,
#     'close': 16399.0,
#     'volume': 0,
#     'adjclose': 16399.0,
#     'formatted_date': '2000-06-08'},
#    {'date': 960555600,
#     'high': 16561.0,
#     'low': 16200.0,
#     'open': 16421.0,
#     'close': 16342.0,
#     'volume': 0,
#     'adjclose': 16342.0,
#     'formatted_date': '2000-06-09'},
#    {'date': 960814800,
#     'high': 16365.0,
#     'low': 16084.0,
#     'open': 16351.0,
#     'close': 16097.0,
#     'volume': 0,
#     'adjclose': 16097.0,
#     'formatted_date': '2000-06-12'},
#    {'date': 960901200,
#     'high': 16360.0,
#     'low': 16075.0,
#     'open': 16100.0,
#     'close': 16354.0,
#     'volume': 0,
#     'adjclose': 16354.0,
#     'formatted_date': '2000-06-13'},
#    {'date': 960987600,
#     'high': 16523.0,
#     'low': 16135.0,
#     'open': 16365.0,
#     'close': 16366.0,
#     'volume': 0,
#     'adjclose': 16366.0,
#     'formatted_date': '2000-06-14'},
#    {'date': 961074000,
#     'high': 16630.0,
#     'low': 16325.0,
#     'open': 16369.0,
#     'close': 16561.0,
#     'volume': 0,
#     'adjclose': 16561.0,
#     'formatted_date': '2000-06-15'},
#    {'date': 961160400,
#     'high': 16598.0,
#     'low': 16379.0,
#     'open': 16567.0,
#     'close': 16425.0,
#     'volume': 0,
#     'adjclose': 16425.0,
#     'formatted_date': '2000-06-16'},
#    {'date': 961419600,
#     'high': 16863.0,
#     'low': 16411.0,
#     'open': 16423.0,
#     'close': 16850.0,
#     'volume': 0,
#     'adjclose': 16850.0,
#     'formatted_date': '2000-06-19'},
#    {'date': 961506000,
#     'high': 16952.0,
#     'low': 16708.0,
#     'open': 16854.0,
#     'close': 16844.0,
#     'volume': 0,
#     'adjclose': 16844.0,
#     'formatted_date': '2000-06-20'},
#    {'date': 961592400,
#     'high': 17396.0,
#     'low': 16834.0,
#     'open': 16854.0,
#     'close': 17254.0,
#     'volume': 0,
#     'adjclose': 17254.0,
#     'formatted_date': '2000-06-21'},
#    {'date': 961678800,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-06-22'},
#    {'date': 961765200,
#     'high': 17266.0,
#     'low': 16910.0,
#     'open': 16977.0,
#     'close': 16977.0,
#     'volume': 0,
#     'adjclose': 16977.0,
#     'formatted_date': '2000-06-23'},
#    {'date': 962024400,
#     'high': 17019.0,
#     'low': 16685.0,
#     'open': 16977.0,
#     'close': 16745.0,
#     'volume': 0,
#     'adjclose': 16745.0,
#     'formatted_date': '2000-06-26'},
#    {'date': 962110800,
#     'high': 16780.0,
#     'low': 16388.0,
#     'open': 16743.0,
#     'close': 16512.0,
#     'volume': 0,
#     'adjclose': 16512.0,
#     'formatted_date': '2000-06-27'},
#    {'date': 962197200,
#     'high': 17101.0,
#     'low': 16493.0,
#     'open': 16532.0,
#     'close': 16842.0,
#     'volume': 0,
#     'adjclose': 16842.0,
#     'formatted_date': '2000-06-28'},
#    {'date': 962283600,
#     'high': 16850.0,
#     'low': 16329.0,
#     'open': 16830.0,
#     'close': 16407.0,
#     'volume': 0,
#     'adjclose': 16407.0,
#     'formatted_date': '2000-06-29'},
#    {'date': 962370000,
#     'high': 16836.0,
#     'low': 16400.0,
#     'open': 16404.0,
#     'close': 16728.0,
#     'volume': 0,
#     'adjclose': 16728.0,
#     'formatted_date': '2000-06-30'},
#    {'date': 962629200,
#     'high': 17099.0,
#     'low': 16743.0,
#     'open': 16747.0,
#     'close': 17089.0,
#     'volume': 0,
#     'adjclose': 17089.0,
#     'formatted_date': '2000-07-03'},
#    {'date': 962715600,
#     'high': 17340.0,
#     'low': 17088.0,
#     'open': 17106.0,
#     'close': 17279.0,
#     'volume': 0,
#     'adjclose': 17279.0,
#     'formatted_date': '2000-07-04'},
#    {'date': 962802000,
#     'high': 17362.0,
#     'low': 17086.0,
#     'open': 17285.0,
#     'close': 17135.0,
#     'volume': 0,
#     'adjclose': 17135.0,
#     'formatted_date': '2000-07-05'},
#    {'date': 962888400,
#     'high': 17366.0,
#     'low': 17024.0,
#     'open': 17148.0,
#     'close': 17348.0,
#     'volume': 0,
#     'adjclose': 17348.0,
#     'formatted_date': '2000-07-06'},
#    {'date': 962974800,
#     'high': 17754.0,
#     'low': 17352.0,
#     'open': 17352.0,
#     'close': 17599.0,
#     'volume': 0,
#     'adjclose': 17599.0,
#     'formatted_date': '2000-07-07'},
#    {'date': 963234000,
#     'high': 17795.0,
#     'low': 17444.0,
#     'open': 17620.0,
#     'close': 17472.0,
#     'volume': 0,
#     'adjclose': 17472.0,
#     'formatted_date': '2000-07-10'},
#    {'date': 963320400,
#     'high': 17473.0,
#     'low': 16827.0,
#     'open': 17473.0,
#     'close': 16881.0,
#     'volume': 0,
#     'adjclose': 16881.0,
#     'formatted_date': '2000-07-11'},
#    {'date': 963406800,
#     'high': 17176.0,
#     'low': 16693.0,
#     'open': 16893.0,
#     'close': 17053.0,
#     'volume': 0,
#     'adjclose': 17053.0,
#     'formatted_date': '2000-07-12'},
#    {'date': 963493200,
#     'high': 17383.0,
#     'low': 16416.0,
#     'open': 17057.0,
#     'close': 16444.0,
#     'volume': 0,
#     'adjclose': 16444.0,
#     'formatted_date': '2000-07-13'},
#    {'date': 963579600,
#     'high': 16885.0,
#     'low': 16390.0,
#     'open': 16439.0,
#     'close': 16881.0,
#     'volume': 0,
#     'adjclose': 16881.0,
#     'formatted_date': '2000-07-14'},
#    {'date': 963838800,
#     'high': 17395.0,
#     'low': 16890.0,
#     'open': 16890.0,
#     'close': 17388.0,
#     'volume': 0,
#     'adjclose': 17388.0,
#     'formatted_date': '2000-07-17'},
#    {'date': 963925200,
#     'high': 17566.0,
#     'low': 17281.0,
#     'open': 17379.0,
#     'close': 17369.0,
#     'volume': 0,
#     'adjclose': 17369.0,
#     'formatted_date': '2000-07-18'},
#    {'date': 964011600,
#     'high': 17358.0,
#     'low': 16868.0,
#     'open': 17354.0,
#     'close': 16928.0,
#     'volume': 0,
#     'adjclose': 16928.0,
#     'formatted_date': '2000-07-19'},
#    {'date': 964098000,
#     'high': 17353.0,
#     'low': 16951.0,
#     'open': 16951.0,
#     'close': 17204.0,
#     'volume': 0,
#     'adjclose': 17204.0,
#     'formatted_date': '2000-07-20'},
#    {'date': 964184400,
#     'high': 17365.0,
#     'low': 17071.0,
#     'open': 17207.0,
#     'close': 17318.0,
#     'volume': 0,
#     'adjclose': 17318.0,
#     'formatted_date': '2000-07-21'},
#    {'date': 964443600,
#     'high': 17588.0,
#     'low': 17314.0,
#     'open': 17314.0,
#     'close': 17386.0,
#     'volume': 0,
#     'adjclose': 17386.0,
#     'formatted_date': '2000-07-24'},
#    {'date': 964530000,
#     'high': 17530.0,
#     'low': 17046.0,
#     'open': 17390.0,
#     'close': 17049.0,
#     'volume': 0,
#     'adjclose': 17049.0,
#     'formatted_date': '2000-07-25'},
#    {'date': 964616400,
#     'high': 17211.0,
#     'low': 16840.0,
#     'open': 17049.0,
#     'close': 17121.0,
#     'volume': 0,
#     'adjclose': 17121.0,
#     'formatted_date': '2000-07-26'},
#    {'date': 964702800,
#     'high': 17225.0,
#     'low': 16923.0,
#     'open': 17121.0,
#     'close': 16949.0,
#     'volume': 0,
#     'adjclose': 16949.0,
#     'formatted_date': '2000-07-27'},
#    {'date': 964789200,
#     'high': 17039.0,
#     'low': 16448.0,
#     'open': 16949.0,
#     'close': 16486.0,
#     'volume': 0,
#     'adjclose': 16486.0,
#     'formatted_date': '2000-07-28'},
#    {'date': 965048400,
#     'high': 16713.0,
#     'low': 16455.0,
#     'open': 16487.0,
#     'close': 16455.0,
#     'volume': 0,
#     'adjclose': 16455.0,
#     'formatted_date': '2000-07-31'},
#    {'date': 965134800,
#     'high': 16591.0,
#     'low': 16127.0,
#     'open': 16475.0,
#     'close': 16290.0,
#     'volume': 0,
#     'adjclose': 16290.0,
#     'formatted_date': '2000-08-01'},
#    {'date': 965221200,
#     'high': 16535.0,
#     'low': 16121.0,
#     'open': 16284.0,
#     'close': 16314.0,
#     'volume': 0,
#     'adjclose': 16314.0,
#     'formatted_date': '2000-08-02'},
#    {'date': 965307600,
#     'high': 16761.0,
#     'low': 16073.0,
#     'open': 16248.0,
#     'close': 16721.0,
#     'volume': 0,
#     'adjclose': 16721.0,
#     'formatted_date': '2000-08-03'},
#    {'date': 965394000,
#     'high': 16907.0,
#     'low': 16716.0,
#     'open': 16727.0,
#     'close': 16761.0,
#     'volume': 0,
#     'adjclose': 16761.0,
#     'formatted_date': '2000-08-04'},
#    {'date': 965653200,
#     'high': 17014.0,
#     'low': 16769.0,
#     'open': 16772.0,
#     'close': 16996.0,
#     'volume': 0,
#     'adjclose': 16996.0,
#     'formatted_date': '2000-08-07'},
#    {'date': 965739600,
#     'high': 17062.0,
#     'low': 16858.0,
#     'open': 17005.0,
#     'close': 16885.0,
#     'volume': 0,
#     'adjclose': 16885.0,
#     'formatted_date': '2000-08-08'},
#    {'date': 965826000,
#     'high': 16977.0,
#     'low': 16511.0,
#     'open': 16894.0,
#     'close': 16534.0,
#     'volume': 0,
#     'adjclose': 16534.0,
#     'formatted_date': '2000-08-09'},
#    {'date': 965912400,
#     'high': 17023.0,
#     'low': 16501.0,
#     'open': 16519.0,
#     'close': 16835.0,
#     'volume': 0,
#     'adjclose': 16835.0,
#     'formatted_date': '2000-08-10'},
#    {'date': 965998800,
#     'high': 17395.0,
#     'low': 16705.0,
#     'open': 16846.0,
#     'close': 17395.0,
#     'volume': 0,
#     'adjclose': 17395.0,
#     'formatted_date': '2000-08-11'},
#    {'date': 966258000,
#     'high': 17926.0,
#     'low': 17334.0,
#     'open': 17402.0,
#     'close': 17811.0,
#     'volume': 0,
#     'adjclose': 17811.0,
#     'formatted_date': '2000-08-14'},
#    {'date': 966344400,
#     'high': 17910.0,
#     'low': 17690.0,
#     'open': 17811.0,
#     'close': 17744.0,
#     'volume': 0,
#     'adjclose': 17744.0,
#     'formatted_date': '2000-08-15'},
#    {'date': 966430800,
#     'high': 17771.0,
#     'low': 17275.0,
#     'open': 17741.0,
#     'close': 17331.0,
#     'volume': 0,
#     'adjclose': 17331.0,
#     'formatted_date': '2000-08-16'},
#    {'date': 966517200,
#     'high': 17858.0,
#     'low': 17321.0,
#     'open': 17326.0,
#     'close': 17703.0,
#     'volume': 0,
#     'adjclose': 17703.0,
#     'formatted_date': '2000-08-17'},
#    {'date': 966603600,
#     'high': 17780.0,
#     'low': 17258.0,
#     'open': 17703.0,
#     'close': 17314.0,
#     'volume': 0,
#     'adjclose': 17314.0,
#     'formatted_date': '2000-08-18'},
#    {'date': 966862800,
#     'high': 17420.0,
#     'low': 17066.0,
#     'open': 17317.0,
#     'close': 17083.0,
#     'volume': 0,
#     'adjclose': 17083.0,
#     'formatted_date': '2000-08-21'},
#    {'date': 966949200,
#     'high': 17428.0,
#     'low': 17086.0,
#     'open': 17086.0,
#     'close': 17224.0,
#     'volume': 0,
#     'adjclose': 17224.0,
#     'formatted_date': '2000-08-22'},
#    {'date': 967035600,
#     'high': 17455.0,
#     'low': 17137.0,
#     'open': 17253.0,
#     'close': 17450.0,
#     'volume': 0,
#     'adjclose': 17450.0,
#     'formatted_date': '2000-08-23'},
#    {'date': 967122000,
#     'high': 17454.0,
#     'low': 17187.0,
#     'open': 17454.0,
#     'close': 17311.0,
#     'volume': 0,
#     'adjclose': 17311.0,
#     'formatted_date': '2000-08-24'},
#    {'date': 967208400,
#     'high': 17668.0,
#     'low': 17316.0,
#     'open': 17316.0,
#     'close': 17643.0,
#     'volume': 0,
#     'adjclose': 17643.0,
#     'formatted_date': '2000-08-25'},
#    {'date': 967467600,
#     'high': 17686.0,
#     'low': 17380.0,
#     'open': 17657.0,
#     'close': 17460.0,
#     'volume': 0,
#     'adjclose': 17460.0,
#     'formatted_date': '2000-08-28'},
#    {'date': 967554000,
#     'high': 17490.0,
#     'low': 17235.0,
#     'open': 17454.0,
#     'close': 17355.0,
#     'volume': 0,
#     'adjclose': 17355.0,
#     'formatted_date': '2000-08-29'},
#    {'date': 967640400,
#     'high': 17563.0,
#     'low': 17309.0,
#     'open': 17359.0,
#     'close': 17414.0,
#     'volume': 0,
#     'adjclose': 17414.0,
#     'formatted_date': '2000-08-30'},
#    {'date': 967726800,
#     'high': 17563.0,
#     'low': 17327.0,
#     'open': 17417.0,
#     'close': 17347.0,
#     'volume': 0,
#     'adjclose': 17347.0,
#     'formatted_date': '2000-08-31'},
#    {'date': 967813200,
#     'high': 17577.0,
#     'low': 17360.0,
#     'open': 17360.0,
#     'close': 17577.0,
#     'volume': 0,
#     'adjclose': 17577.0,
#     'formatted_date': '2000-09-01'},
#    {'date': 968072400,
#     'high': 17716.0,
#     'low': 17569.0,
#     'open': 17577.0,
#     'close': 17613.0,
#     'volume': 0,
#     'adjclose': 17613.0,
#     'formatted_date': '2000-09-04'},
#    {'date': 968158800,
#     'high': 17639.0,
#     'low': 17417.0,
#     'open': 17614.0,
#     'close': 17425.0,
#     'volume': 0,
#     'adjclose': 17425.0,
#     'formatted_date': '2000-09-05'},
#    {'date': 968245200,
#     'high': 17648.0,
#     'low': 17442.0,
#     'open': 17442.0,
#     'close': 17590.0,
#     'volume': 0,
#     'adjclose': 17590.0,
#     'formatted_date': '2000-09-06'},
#    {'date': 968331600,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-09-07'},
#    {'date': 968418000,
#     'high': 17692.0,
#     'low': 17428.0,
#     'open': 17594.0,
#     'close': 17433.0,
#     'volume': 0,
#     'adjclose': 17433.0,
#     'formatted_date': '2000-09-08'},
#    {'date': 968677200,
#     'high': 17475.0,
#     'low': 17236.0,
#     'open': 17443.0,
#     'close': 17288.0,
#     'volume': 0,
#     'adjclose': 17288.0,
#     'formatted_date': '2000-09-11'},
#    {'date': 968763600,
#     'high': 17304.0,
#     'low': 16883.0,
#     'open': 17285.0,
#     'close': 16883.0,
#     'volume': 0,
#     'adjclose': 16883.0,
#     'formatted_date': '2000-09-12'},
#    {'date': 968850000,
#     'high': 17092.0,
#     'low': 16877.0,
#     'open': 16888.0,
#     'close': 16999.0,
#     'volume': 0,
#     'adjclose': 16999.0,
#     'formatted_date': '2000-09-13'},
#    {'date': 968936400,
#     'high': 17108.0,
#     'low': 16731.0,
#     'open': 17032.0,
#     'close': 16769.0,
#     'volume': 0,
#     'adjclose': 16769.0,
#     'formatted_date': '2000-09-14'},
#    {'date': 969022800,
#     'high': 16771.0,
#     'low': 16515.0,
#     'open': 16771.0,
#     'close': 16563.0,
#     'volume': 0,
#     'adjclose': 16563.0,
#     'formatted_date': '2000-09-15'},
#    {'date': 969282000,
#     'high': 16609.0,
#     'low': 15913.0,
#     'open': 16562.0,
#     'close': 15913.0,
#     'volume': 0,
#     'adjclose': 15913.0,
#     'formatted_date': '2000-09-18'},
#    {'date': 969368400,
#     'high': 16189.0,
#     'low': 15824.0,
#     'open': 15923.0,
#     'close': 16188.0,
#     'volume': 0,
#     'adjclose': 16188.0,
#     'formatted_date': '2000-09-19'},
#    {'date': 969454800,
#     'high': 16216.0,
#     'low': 15813.0,
#     'open': 16196.0,
#     'close': 16078.0,
#     'volume': 0,
#     'adjclose': 16078.0,
#     'formatted_date': '2000-09-20'},
#    {'date': 969541200,
#     'high': 16172.0,
#     'low': 15946.0,
#     'open': 16065.0,
#     'close': 16146.0,
#     'volume': 0,
#     'adjclose': 16146.0,
#     'formatted_date': '2000-09-21'},
#    {'date': 969627600,
#     'high': 16426.0,
#     'low': 15705.0,
#     'open': 16093.0,
#     'close': 16353.0,
#     'volume': 0,
#     'adjclose': 16353.0,
#     'formatted_date': '2000-09-22'},
#    {'date': 969886800,
#     'high': 16521.0,
#     'low': 16318.0,
#     'open': 16361.0,
#     'close': 16319.0,
#     'volume': 0,
#     'adjclose': 16319.0,
#     'formatted_date': '2000-09-25'},
#    {'date': 969973200,
#     'high': 16468.0,
#     'low': 16196.0,
#     'open': 16319.0,
#     'close': 16255.0,
#     'volume': 0,
#     'adjclose': 16255.0,
#     'formatted_date': '2000-09-26'},
#    {'date': 970059600,
#     'high': 16404.0,
#     'low': 15745.0,
#     'open': 16289.0,
#     'close': 15848.0,
#     'volume': 0,
#     'adjclose': 15848.0,
#     'formatted_date': '2000-09-27'},
#    {'date': 970146000,
#     'high': 16041.0,
#     'low': 15657.0,
#     'open': 15849.0,
#     'close': 16014.0,
#     'volume': 0,
#     'adjclose': 16014.0,
#     'formatted_date': '2000-09-28'},
#    {'date': 970232400,
#     'high': 16135.0,
#     'low': 15821.0,
#     'open': 16020.0,
#     'close': 15928.0,
#     'volume': 0,
#     'adjclose': 15928.0,
#     'formatted_date': '2000-09-29'},
#    {'date': 970491600,
#     'high': 16090.0,
#     'low': 15537.0,
#     'open': 15950.0,
#     'close': 15559.0,
#     'volume': 0,
#     'adjclose': 15559.0,
#     'formatted_date': '2000-10-02'},
#    {'date': 970578000,
#     'high': 15917.0,
#     'low': 15562.0,
#     'open': 15562.0,
#     'close': 15633.0,
#     'volume': 0,
#     'adjclose': 15633.0,
#     'formatted_date': '2000-10-03'},
#    {'date': 970664400,
#     'high': 15883.0,
#     'low': 15651.0,
#     'open': 15653.0,
#     'close': 15876.0,
#     'volume': 0,
#     'adjclose': 15876.0,
#     'formatted_date': '2000-10-04'},
#    {'date': 970750800,
#     'high': 16398.0,
#     'low': 15876.0,
#     'open': 15876.0,
#     'close': 16362.0,
#     'volume': 0,
#     'adjclose': 16362.0,
#     'formatted_date': '2000-10-05'},
#    {'date': 970837200,
#     'high': 16404.0,
#     'low': 15817.0,
#     'open': 16370.0,
#     'close': 15946.0,
#     'volume': 0,
#     'adjclose': 15946.0,
#     'formatted_date': '2000-10-06'},
#    {'date': 971092800,
#     'high': 15975.0,
#     'low': 15617.0,
#     'open': 15946.0,
#     'close': 15855.0,
#     'volume': 0,
#     'adjclose': 15855.0,
#     'formatted_date': '2000-10-09'},
#    {'date': 971179200,
#     'high': 16008.0,
#     'low': 15726.0,
#     'open': 15846.0,
#     'close': 15747.0,
#     'volume': 0,
#     'adjclose': 15747.0,
#     'formatted_date': '2000-10-10'},
#    {'date': 971265600,
#     'high': 15738.0,
#     'low': 15463.0,
#     'open': 15738.0,
#     'close': 15526.0,
#     'volume': 0,
#     'adjclose': 15526.0,
#     'formatted_date': '2000-10-11'},
#    {'date': 971352000,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-10-12'},
#    {'date': 971438400,
#     'high': 15441.0,
#     'low': 15067.0,
#     'open': 15441.0,
#     'close': 15385.0,
#     'volume': 0,
#     'adjclose': 15385.0,
#     'formatted_date': '2000-10-13'},
#    {'date': 971697600,
#     'high': 15585.0,
#     'low': 15214.0,
#     'open': 15387.0,
#     'close': 15242.0,
#     'volume': 0,
#     'adjclose': 15242.0,
#     'formatted_date': '2000-10-16'},
#    {'date': 971784000,
#     'high': 15386.0,
#     'low': 14841.0,
#     'open': 15267.0,
#     'close': 14870.0,
#     'volume': 0,
#     'adjclose': 14870.0,
#     'formatted_date': '2000-10-17'},
#    {'date': 971870400,
#     'high': 14837.0,
#     'low': 14218.0,
#     'open': 14837.0,
#     'close': 14421.0,
#     'volume': 0,
#     'adjclose': 14421.0,
#     'formatted_date': '2000-10-18'},
#    {'date': 971956800,
#     'high': 14869.0,
#     'low': 14490.0,
#     'open': 14490.0,
#     'close': 14845.0,
#     'volume': 0,
#     'adjclose': 14845.0,
#     'formatted_date': '2000-10-19'},
#    {'date': 972043200,
#     'high': 14918.0,
#     'low': 14490.0,
#     'open': 14846.0,
#     'close': 14529.0,
#     'volume': 0,
#     'adjclose': 14529.0,
#     'formatted_date': '2000-10-20'},
#    {'date': 972302400,
#     'high': 14535.0,
#     'low': 13982.0,
#     'open': 14533.0,
#     'close': 13990.0,
#     'volume': 0,
#     'adjclose': 13990.0,
#     'formatted_date': '2000-10-23'},
#    {'date': 972388800,
#     'high': 14161.0,
#     'low': 13672.0,
#     'open': 14014.0,
#     'close': 13799.0,
#     'volume': 0,
#     'adjclose': 13799.0,
#     'formatted_date': '2000-10-24'},
#    {'date': 972475200,
#     'high': 13927.0,
#     'low': 13571.0,
#     'open': 13796.0,
#     'close': 13665.0,
#     'volume': 0,
#     'adjclose': 13665.0,
#     'formatted_date': '2000-10-25'},
#    {'date': 972561600,
#     'high': 14223.0,
#     'low': 13679.0,
#     'open': 13705.0,
#     'close': 14223.0,
#     'volume': 0,
#     'adjclose': 14223.0,
#     'formatted_date': '2000-10-26'},
#    {'date': 972648000,
#     'high': 14700.0,
#     'low': 14251.0,
#     'open': 14251.0,
#     'close': 14692.0,
#     'volume': 0,
#     'adjclose': 14692.0,
#     'formatted_date': '2000-10-27'},
#    {'date': 972907200,
#     'high': 14951.0,
#     'low': 14489.0,
#     'open': 14707.0,
#     'close': 14891.0,
#     'volume': 0,
#     'adjclose': 14891.0,
#     'formatted_date': '2000-10-30'},
#    {'date': 972993600,
#     'high': 15099.0,
#     'low': 14859.0,
#     'open': 14916.0,
#     'close': 14867.0,
#     'volume': 0,
#     'adjclose': 14867.0,
#     'formatted_date': '2000-10-31'},
#    {'date': 973080000,
#     'high': 14859.0,
#     'low': 14571.0,
#     'open': 14858.0,
#     'close': 14791.0,
#     'volume': 0,
#     'adjclose': 14791.0,
#     'formatted_date': '2000-11-01'},
#    {'date': 973166400,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-11-02'},
#    {'date': 973252800,
#     'high': 14925.0,
#     'low': 14425.0,
#     'open': 14785.0,
#     'close': 14534.0,
#     'volume': 0,
#     'adjclose': 14534.0,
#     'formatted_date': '2000-11-03'},
#    {'date': 973512000,
#     'high': 14868.0,
#     'low': 14478.0,
#     'open': 14534.0,
#     'close': 14801.0,
#     'volume': 0,
#     'adjclose': 14801.0,
#     'formatted_date': '2000-11-06'},
#    {'date': 973598400,
#     'high': 15029.0,
#     'low': 14543.0,
#     'open': 14780.0,
#     'close': 14969.0,
#     'volume': 0,
#     'adjclose': 14969.0,
#     'formatted_date': '2000-11-07'},
#    {'date': 973684800,
#     'high': 15191.0,
#     'low': 14650.0,
#     'open': 14982.0,
#     'close': 14656.0,
#     'volume': 0,
#     'adjclose': 14656.0,
#     'formatted_date': '2000-11-08'},
#    {'date': 973771200,
#     'high': 14782.0,
#     'low': 14409.0,
#     'open': 14667.0,
#     'close': 14524.0,
#     'volume': 0,
#     'adjclose': 14524.0,
#     'formatted_date': '2000-11-09'},
#    {'date': 973857600,
#     'high': 14701.0,
#     'low': 14449.0,
#     'open': 14542.0,
#     'close': 14626.0,
#     'volume': 0,
#     'adjclose': 14626.0,
#     'formatted_date': '2000-11-10'},
#    {'date': 974116800,
#     'high': 14609.0,
#     'low': 14199.0,
#     'open': 14606.0,
#     'close': 14372.0,
#     'volume': 0,
#     'adjclose': 14372.0,
#     'formatted_date': '2000-11-13'},
#    {'date': 974203200,
#     'high': 14632.0,
#     'low': 14395.0,
#     'open': 14395.0,
#     'close': 14540.0,
#     'volume': 0,
#     'adjclose': 14540.0,
#     'formatted_date': '2000-11-14'},
#    {'date': 974289600,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-11-15'},
#    {'date': 974376000,
#     'high': 14575.0,
#     'low': 14419.0,
#     'open': 14546.0,
#     'close': 14490.0,
#     'volume': 0,
#     'adjclose': 14490.0,
#     'formatted_date': '2000-11-16'},
#    {'date': 974462400,
#     'high': 14570.0,
#     'low': 14091.0,
#     'open': 14479.0,
#     'close': 14323.0,
#     'volume': 0,
#     'adjclose': 14323.0,
#     'formatted_date': '2000-11-17'},
#    {'date': 974721600,
#     'high': 14535.0,
#     'low': 14103.0,
#     'open': 14323.0,
#     'close': 14500.0,
#     'volume': 0,
#     'adjclose': 14500.0,
#     'formatted_date': '2000-11-20'},
#    {'date': 974808000,
#     'high': 14845.0,
#     'low': 14487.0,
#     'open': 14497.0,
#     'close': 14784.0,
#     'volume': 0,
#     'adjclose': 14784.0,
#     'formatted_date': '2000-11-21'},
#    {'date': 974894400,
#     'high': 14766.0,
#     'low': 14555.0,
#     'open': 14766.0,
#     'close': 14577.0,
#     'volume': 0,
#     'adjclose': 14577.0,
#     'formatted_date': '2000-11-22'},
#    {'date': 974980800,
#     'high': 14604.0,
#     'low': 14187.0,
#     'open': 14579.0,
#     'close': 14314.0,
#     'volume': 0,
#     'adjclose': 14314.0,
#     'formatted_date': '2000-11-23'},
#    {'date': 975067200,
#     'high': 14413.0,
#     'low': 12969.0,
#     'open': 14316.0,
#     'close': 14336.0,
#     'volume': 0,
#     'adjclose': 14336.0,
#     'formatted_date': '2000-11-24'},
#    {'date': 975326400,
#     'high': 14495.0,
#     'low': 13941.0,
#     'open': 14340.0,
#     'close': 14008.0,
#     'volume': 0,
#     'adjclose': 14008.0,
#     'formatted_date': '2000-11-27'},
#    {'date': 975412800,
#     'high': 14011.0,
#     'low': 13756.0,
#     'open': 14011.0,
#     'close': 13914.0,
#     'volume': 0,
#     'adjclose': 13914.0,
#     'formatted_date': '2000-11-28'},
#    {'date': 975499200,
#     'high': 14074.0,
#     'low': 13782.0,
#     'open': 13921.0,
#     'close': 13788.0,
#     'volume': 0,
#     'adjclose': 13788.0,
#     'formatted_date': '2000-11-29'},
#    {'date': 975585600,
#     'high': 13779.0,
#     'low': 13287.0,
#     'open': 13779.0,
#     'close': 13287.0,
#     'volume': 0,
#     'adjclose': 13287.0,
#     'formatted_date': '2000-11-30'},
#    {'date': 975672000,
#     'high': 13578.0,
#     'low': 13282.0,
#     'open': 13303.0,
#     'close': 13437.0,
#     'volume': 0,
#     'adjclose': 13437.0,
#     'formatted_date': '2000-12-01'},
#    {'date': 975931200,
#     'high': 13538.0,
#     'low': 13242.0,
#     'open': 13396.0,
#     'close': 13510.0,
#     'volume': 0,
#     'adjclose': 13510.0,
#     'formatted_date': '2000-12-04'},
#    {'date': 976017600,
#     'high': 14188.0,
#     'low': 13513.0,
#     'open': 13513.0,
#     'close': 14182.0,
#     'volume': 0,
#     'adjclose': 14182.0,
#     'formatted_date': '2000-12-05'},
#    {'date': 976104000,
#     'high': 14277.0,
#     'low': 13945.0,
#     'open': 14180.0,
#     'close': 13945.0,
#     'volume': 0,
#     'adjclose': 13945.0,
#     'formatted_date': '2000-12-06'},
#    {'date': 976190400,
#     'high': 14460.0,
#     'low': 13918.0,
#     'open': 13947.0,
#     'close': 14460.0,
#     'volume': 0,
#     'adjclose': 14460.0,
#     'formatted_date': '2000-12-07'},
#    {'date': 976276800,
#     'high': 15062.0,
#     'low': 14461.0,
#     'open': 14462.0,
#     'close': 14983.0,
#     'volume': 0,
#     'adjclose': 14983.0,
#     'formatted_date': '2000-12-08'},
#    {'date': 976536000,
#     'high': 15355.0,
#     'low': 14991.0,
#     'open': 14991.0,
#     'close': 15188.0,
#     'volume': 0,
#     'adjclose': 15188.0,
#     'formatted_date': '2000-12-11'},
#    {'date': 976622400,
#     'high': 15186.0,
#     'low': 14869.0,
#     'open': 15186.0,
#     'close': 14906.0,
#     'volume': 0,
#     'adjclose': 14906.0,
#     'formatted_date': '2000-12-12'},
#    {'date': 976708800,
#     'high': 15389.0,
#     'low': 14900.0,
#     'open': 14916.0,
#     'close': 15291.0,
#     'volume': 0,
#     'adjclose': 15291.0,
#     'formatted_date': '2000-12-13'},
#    {'date': 976795200,
#     'high': 15329.0,
#     'low': 15080.0,
#     'open': 15261.0,
#     'close': 15259.0,
#     'volume': 0,
#     'adjclose': 15259.0,
#     'formatted_date': '2000-12-14'},
#    {'date': 976881600,
#     'high': 15253.0,
#     'low': 14833.0,
#     'open': 15253.0,
#     'close': 14988.0,
#     'volume': 0,
#     'adjclose': 14988.0,
#     'formatted_date': '2000-12-15'},
#    {'date': 977140800,
#     'high': 15282.0,
#     'low': 14093.0,
#     'open': 15002.0,
#     'close': 15083.0,
#     'volume': 0,
#     'adjclose': 15083.0,
#     'formatted_date': '2000-12-18'},
#    {'date': 977227200,
#     'high': 15415.0,
#     'low': 15085.0,
#     'open': 15085.0,
#     'close': 15336.0,
#     'volume': 0,
#     'adjclose': 15336.0,
#     'formatted_date': '2000-12-19'},
#    {'date': 977313600,
#     'high': 15328.0,
#     'low': 14618.0,
#     'open': 15306.0,
#     'close': 14622.0,
#     'volume': 0,
#     'adjclose': 14622.0,
#     'formatted_date': '2000-12-20'},
#    {'date': 977400000,
#     'high': 14958.0,
#     'low': 14461.0,
#     'open': 14727.0,
#     'close': 14505.0,
#     'volume': 0,
#     'adjclose': 14505.0,
#     'formatted_date': '2000-12-21'},
#    {'date': 977486400,
#     'high': 14802.0,
#     'low': 14532.0,
#     'open': 14533.0,
#     'close': 14652.0,
#     'volume': 0,
#     'adjclose': 14652.0,
#     'formatted_date': '2000-12-22'},
#    {'date': 977745600,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2000-12-25'},
#    {'date': 977832000,
#     'high': 14851.0,
#     'low': 14659.0,
#     'open': 14663.0,
#     'close': 14795.0,
#     'volume': 0,
#     'adjclose': 14795.0,
#     'formatted_date': '2000-12-26'},
#    {'date': 977918400,
#     'high': 15223.0,
#     'low': 14805.0,
#     'open': 14805.0,
#     'close': 15186.0,
#     'volume': 0,
# ...
#     'close': 13281.0,
#     'volume': 0,
#     'adjclose': 13281.0,
#     'formatted_date': '2003-07-04'},
#    {'date': 1057582800,
#     'high': 13444.0,
#     'low': 13273.0,
#     'open': 13274.0,
#     'close': 13402.0,
#     'volume': 0,
#     'adjclose': 13402.0,
#     'formatted_date': '2003-07-07'},
#    {'date': 1057669200,
#     'high': 13619.0,
#     'low': 13339.0,
#     'open': 13401.0,
#     'close': 13619.0,
#     'volume': 0,
#     'adjclose': 13619.0,
#     'formatted_date': '2003-07-08'},
#    {'date': 1057755600,
#     'high': None,
#     'low': None,
#     'open': None,
#     'close': None,
#     'volume': None,
#     'adjclose': None,
#     'formatted_date': '2003-07-09'},
#    {'date': 1057842000,
#     'high': 13622.0,
#     'low': 13407.0,
#     'open': 13622.0,
#     'close': 13501.0,
#     'volume': 0,
#     'adjclose': 13501.0,
#     'formatted_date': '2003-07-10'},
#    {'date': 1057928400,
#     'high': 13522.0,
#     'low': 13287.0,
#     'open': 13498.0,
#     'close': 13321.0,
#     'volume': 0,
#     'adjclose': 13321.0,
#     'formatted_date': '2003-07-11'},
#    {'date': 1058187600,
#     'high': 13635.0,
#     'low': 13322.0,
#     'open': 13322.0,
#     'close': 13588.0,
#     'volume': 0,
#     'adjclose': 13588.0,
#     'formatted_date': '2003-07-14'},
#    {'date': 1058274000,
#     'high': 13736.0,
#     'low': 13568.0,
#     'open': 13593.0,
#     'close': 13614.0,
#     'volume': 0,
#     'adjclose': 13614.0,
#     'formatted_date': '2003-07-15'},
#    {'date': 1058360400,
#     'high': 13633.0,
#     'low': 13435.0,
#     'open': 13613.0,
#     'close': 13487.0,
#     'volume': 0,
#     'adjclose': 13487.0,
#     'formatted_date': '2003-07-16'},
#    {'date': 1058446800,
#     'high': 13636.0,
#     'low': 13360.0,
#     'open': 13487.0,
#     'close': 13622.0,
#     'volume': 0,
#     'adjclose': 13622.0,
#     'formatted_date': '2003-07-17'},
#    {'date': 1058533200,
#     'high': 13809.0,
#     'low': 13622.0,
#     'open': 13622.0,
#     'close': 13794.0,
#     'volume': 0,
#     'adjclose': 13794.0,
#     'formatted_date': '2003-07-18'},
#    {'date': 1058792400,
#     'high': 13859.0,
#     'low': 13676.0,
#     'open': 13794.0,
#     'close': 13676.0,
#     'volume': 0,
#     'adjclose': 13676.0,
#     'formatted_date': '2003-07-21'},
#    {'date': 1058878800,
#     'high': 13867.0,
#     'low': 13671.0,
#     'open': 13676.0,
#     'close': 13835.0,
#     'volume': 0,
#     'adjclose': 13835.0,
#     'formatted_date': '2003-07-22'},
#    {'date': 1058965200,
#     'high': 13942.0,
#     'low': 13755.0,
#     'open': 13852.0,
#     'close': 13799.0,
#     'volume': 0,
#     'adjclose': 13799.0,
#     'formatted_date': '2003-07-23'},
#    {'date': 1059051600,
#     'high': 13947.0,
#     'low': 13755.0,
#     'open': 13799.0,
#     'close': 13761.0,
#     'volume': 0,
#     'adjclose': 13761.0,
#     'formatted_date': '2003-07-24'},
#    {'date': 1059138000,
#     'high': 13868.0,
#     'low': 13661.0,
#     'open': 13761.0,
#     'close': 13750.0,
#     'volume': 0,
#     'adjclose': 13750.0,
#     'formatted_date': '2003-07-25'},
#    {'date': 1059397200,
#     'high': 13783.0,
#     'low': 13605.0,
#     'open': 13752.0,
#     'close': 13643.0,
#     'volume': 0,
#     'adjclose': 13643.0,
#     'formatted_date': '2003-07-28'},
#    {'date': 1059483600,
#     'high': 13704.0,
#     'low': 13577.0,
#     'open': 13652.0,
#     'close': 13623.0,
#     'volume': 0,
#     'adjclose': 13623.0,
#     'formatted_date': '2003-07-29'},
#    {'date': 1059570000,
#     'high': 13698.0,
#     'low': 13453.0,
#     'open': 13623.0,
#     'close': 13475.0,
#     'volume': 0,
#     'adjclose': 13475.0,
#     'formatted_date': '2003-07-30'},
#    {'date': 1059656400,
#     'high': 13615.0,
#     'low': 13475.0,
#     'open': 13475.0,
#     'close': 13572.0,
#     'volume': 0,
#     'adjclose': 13572.0,
#     'formatted_date': '2003-07-31'},
#    {'date': 1059742800,
#     'high': 13579.0,
#     'low': 13130.0,
#     'open': 13579.0,
#     'close': 13130.0,
#     'volume': 0,
#     'adjclose': 13130.0,
#     'formatted_date': '2003-08-01'},
#    {'date': 1060002000,
#     'high': 13128.0,
#     'low': 12757.0,
#     'open': 13128.0,
#     'close': 12939.0,
#     'volume': 0,
#     'adjclose': 12939.0,
#     'formatted_date': '2003-08-04'},
#    {'date': 1060088400,
#     'high': 13112.0,
#     'low': 12940.0,
#     'open': 12940.0,
#     'close': 13059.0,
#     'volume': 0,
#     'adjclose': 13059.0,
#     'formatted_date': '2003-08-05'},
#    {'date': 1060174800,
#     'high': 13188.0,
#     'low': 12839.0,
#     'open': 13060.0,
#     'close': 12888.0,
#     'volume': 0,
#     'adjclose': 12888.0,
#     'formatted_date': '2003-08-06'},
#    {'date': 1060261200,
#     'high': 13350.0,
#     'low': 12892.0,
#     'open': 12892.0,
#     'close': 13328.0,
#     'volume': 0,
#     'adjclose': 13328.0,
#     'formatted_date': '2003-08-07'},
#    {'date': 1060347600,
#     'high': 13513.0,
#     'low': 13333.0,
#     'open': 13333.0,
#     'close': 13500.0,
#     'volume': 0,
#     'adjclose': 13500.0,
#     'formatted_date': '2003-08-08'},
#    {'date': 1060606800,
#     'high': 13582.0,
#     'low': 13442.0,
#     'open': 13500.0,
#     'close': 13560.0,
#     'volume': 0,
#     'adjclose': 13560.0,
#     'formatted_date': '2003-08-11'},
#    {'date': 1060693200,
#     'high': 13766.0,
#     'low': 13553.0,
#     'open': 13559.0,
#     'close': 13602.0,
#     'volume': 0,
#     'adjclose': 13602.0,
#     'formatted_date': '2003-08-12'},
#    {'date': 1060779600,
#     'high': 13858.0,
#     'low': 13542.0,
#     'open': 13597.0,
#     'close': 13682.0,
#     'volume': 0,
#     'adjclose': 13682.0,
#     'formatted_date': '2003-08-13'},
#    {'date': 1060866000,
#     'high': 13849.0,
#     'low': 13529.0,
#     'open': 13683.0,
#     'close': 13812.0,
#     'volume': 0,
#     'adjclose': 13812.0,
#     'formatted_date': '2003-08-14'},
#    {'date': 1060952400,
#     'high': 13952.0,
#     'low': 13744.0,
#     'open': 13810.0,
#     'close': 13890.0,
#     'volume': 0,
#     'adjclose': 13890.0,
#     'formatted_date': '2003-08-15'},
#    {'date': 1061211600,
#     'high': 14147.0,
#     'low': 13900.0,
#     'open': 13900.0,
#     'close': 14146.0,
#     'volume': 0,
#     'adjclose': 14146.0,
#     'formatted_date': '2003-08-18'},
#    {'date': 1061298000,
#     'high': 14236.0,
#     'low': 14091.0,
#     'open': 14147.0,
#     'close': 14158.0,
#     'volume': 0,
#     'adjclose': 14158.0,
#     'formatted_date': '2003-08-19'},
#    {'date': 1061384400,
#     'high': 14506.0,
#     'low': 14058.0,
#     'open': 14158.0,
#     'close': 14467.0,
#     'volume': 0,
#     'adjclose': 14467.0,
#     'formatted_date': '2003-08-20'},
#    {'date': 1061470800,
#     'high': 14687.0,
#     'low': 14398.0,
#     'open': 14470.0,
#     'close': 14670.0,
#     'volume': 0,
#     'adjclose': 14670.0,
#     'formatted_date': '2003-08-21'},
#    {'date': 1061557200,
#     'high': 14765.0,
#     'low': 14589.0,
#     'open': 14670.0,
#     'close': 14613.0,
#     'volume': 0,
#     'adjclose': 14613.0,
#     'formatted_date': '2003-08-22'},
#    {'date': 1061816400,
#     'high': 14714.0,
#     'low': 14426.0,
#     'open': 14613.0,
#     'close': 14473.0,
#     'volume': 0,
#     'adjclose': 14473.0,
#     'formatted_date': '2003-08-25'},
#    {'date': 1061902800,
#     'high': 14948.0,
#     'low': 14425.0,
#     'open': 14475.0,
#     'close': 14878.0,
#     'volume': 0,
#     'adjclose': 14878.0,
#     'formatted_date': '2003-08-26'},
#    {'date': 1061989200,
#     'high': 15143.0,
#     'low': 14876.0,
#     'open': 14876.0,
#     'close': 15143.0,
#     'volume': 0,
#     'adjclose': 15143.0,
#     'formatted_date': '2003-08-27'},
#    {'date': 1062075600,
#     'high': 15252.0,
#     'low': 14929.0,
#     'open': 15151.0,
#     'close': 15065.0,
#     'volume': 0,
#     'adjclose': 15065.0,
#     'formatted_date': '2003-08-28'},
#    {'date': 1062162000,
#     'high': 15197.0,
#     'low': 14857.0,
#     'open': 15065.0,
#     'close': 15174.0,
#     'volume': 0,
#     'adjclose': 15174.0,
#     'formatted_date': '2003-08-29'},
#    {'date': 1062421200,
#     'high': 15374.0,
#     'low': 15075.0,
#     'open': 15174.0,
#     'close': 15352.0,
#     'volume': 0,
#     'adjclose': 15352.0,
#     'formatted_date': '2003-09-01'},
#    {'date': 1062507600,
#     'high': 15475.0,
#     'low': 15321.0,
#     'open': 15352.0,
#     'close': 15454.0,
#     'volume': 0,
#     'adjclose': 15454.0,
#     'formatted_date': '2003-09-02'},
#    {'date': 1062594000,
#     'high': 15690.0,
#     'low': 15455.0,
#     'open': 15455.0,
#     'close': 15634.0,
#     'volume': 0,
#     'adjclose': 15634.0,
#     'formatted_date': '2003-09-03'},
#    {'date': 1062680400,
#     'high': 15884.0,
#     'low': 15564.0,
#     'open': 15635.0,
#     'close': 15705.0,
#     'volume': 0,
#     'adjclose': 15705.0,
#     'formatted_date': '2003-09-04'},
#    {'date': 1062766800,
#     'high': 15951.0,
#     'low': 15610.0,
#     'open': 15707.0,
#     'close': 15900.0,
#     'volume': 0,
#     'adjclose': 15900.0,
#     'formatted_date': '2003-09-05'},
#    {'date': 1063026000,
#     'high': 16239.0,
#     'low': 15895.0,
#     'open': 15904.0,
#     'close': 16050.0,
#     'volume': 0,
#     'adjclose': 16050.0,
#     'formatted_date': '2003-09-08'},
#    {'date': 1063112400,
#     'high': 16062.0,
#     'low': 15699.0,
#     'open': 16051.0,
#     'close': 15718.0,
#     'volume': 0,
#     'adjclose': 15718.0,
#     'formatted_date': '2003-09-09'},
#    {'date': 1063198800,
#     'high': 15997.0,
#     'low': 15492.0,
#     'open': 15716.0,
#     'close': 15983.0,
#     'volume': 0,
#     'adjclose': 15983.0,
#     'formatted_date': '2003-09-10'},
#    {'date': 1063285200,
#     'high': 16454.0,
#     'low': 15985.0,
#     'open': 15985.0,
#     'close': 16292.0,
#     'volume': 0,
#     'adjclose': 16292.0,
#     'formatted_date': '2003-09-11'},
#    {'date': 1063371600,
#     'high': 16508.0,
#     'low': 16058.0,
#     'open': 16283.0,
#     'close': 16421.0,
#     'volume': 0,
#     'adjclose': 16421.0,
#     'formatted_date': '2003-09-12'},
#    {'date': 1063630800,
#     'high': 16601.0,
#     'low': 16277.0,
#     'open': 16423.0,
#     'close': 16342.0,
#     'volume': 0,
#     'adjclose': 16342.0,
#     'formatted_date': '2003-09-15'},
#    {'date': 1063717200,
#     'high': 16496.0,
#     'low': 16258.0,
#     'open': 16354.0,
#     'close': 16270.0,
#     'volume': 0,
#     'adjclose': 16270.0,
#     'formatted_date': '2003-09-16'},
#    {'date': 1063803600,
#     'high': 16492.0,
#     'low': 16225.0,
#     'open': 16280.0,
#     'close': 16492.0,
#     'volume': 0,
#     'adjclose': 16492.0,
#     'formatted_date': '2003-09-17'},
#    {'date': 1063890000,
#     'high': 16911.0,
#     'low': 16424.0,
#     'open': 16492.0,
#     'close': 16889.0,
#     'volume': 0,
#     'adjclose': 16889.0,
#     'formatted_date': '2003-09-18'},
#    {'date': 1063976400,
#     'high': 17104.0,
#     'low': 16822.0,
#     'open': 16890.0,
#     'close': 16851.0,
#     'volume': 0,
#     'adjclose': 16851.0,
#     'formatted_date': '2003-09-19'},
#    {'date': 1064235600,
#     'high': 16850.0,
#     'low': 16450.0,
#     'open': 16850.0,
#     'close': 16486.0,
#     'volume': 0,
#     'adjclose': 16486.0,
#     'formatted_date': '2003-09-22'},
#    {'date': 1064322000,
#     'high': 16542.0,
#     'low': 16226.0,
#     'open': 16488.0,
#     'close': 16444.0,
#     'volume': 0,
#     'adjclose': 16444.0,
#     'formatted_date': '2003-09-23'},
#    {'date': 1064408400,
#     'high': 16636.0,
#     'low': 16053.0,
#     'open': 16446.0,
#     'close': 16058.0,
#     'volume': 0,
#     'adjclose': 16058.0,
#     'formatted_date': '2003-09-24'},
#    {'date': 1064494800,
#     'high': 16203.0,
#     'low': 15775.0,
#     'open': 16058.0,
#     'close': 15806.0,
#     'volume': 0,
#     'adjclose': 15806.0,
#     'formatted_date': '2003-09-25'},
#    {'date': 1064581200,
#     'high': 16113.0,
#     'low': 15773.0,
#     'open': 15807.0,
#     'close': 15811.0,
#     'volume': 0,
#     'adjclose': 15811.0,
#     'formatted_date': '2003-09-26'},
#    {'date': 1064840400,
#     'high': 16115.0,
#     'low': 15768.0,
#     'open': 15810.0,
#     'close': 16109.0,
#     'volume': 0,
#     'adjclose': 16109.0,
#     'formatted_date': '2003-09-29'},
#    {'date': 1064926800,
#     'high': 16287.0,
#     'low': 16010.0,
#     'open': 16109.0,
#     'close': 16011.0,
#     'volume': 0,
#     'adjclose': 16011.0,
#     'formatted_date': '2003-09-30'},
#    {'date': 1065013200,
#     'high': 16609.0,
#     'low': 16010.0,
#     'open': 16010.0,
#     'close': 16579.0,
#     'volume': 0,
#     'adjclose': 16579.0,
#     'formatted_date': '2003-10-01'},
#    {'date': 1065099600,
#     'high': 17070.0,
#     'low': 16582.0,
#     'open': 16582.0,
#     'close': 16894.0,
#     'volume': 0,
#     'adjclose': 16894.0,
#     'formatted_date': '2003-10-02'},
#    {'date': 1065186000,
#     'high': 17290.0,
#     'low': 16898.0,
#     'open': 16898.0,
#     'close': 17089.0,
#     'volume': 0,
#     'adjclose': 17089.0,
#     'formatted_date': '2003-10-03'},
#    {'date': 1065445200,
#     'high': 17346.0,
#     'low': 17026.0,
#     'open': 17090.0,
#     'close': 17273.0,
#     'volume': 0,
#     'adjclose': 17273.0,
#     'formatted_date': '2003-10-06'},
#    {'date': 1065531600,
#     'high': 17537.0,
#     'low': 17134.0,
#     'open': 17278.0,
#     'close': 17470.0,
#     'volume': 0,
#     'adjclose': 17470.0,
#     'formatted_date': '2003-10-07'},
#    {'date': 1065618000,
#     'high': 17952.0,
#     'low': 17474.0,
#     'open': 17474.0,
#     'close': 17805.0,
#     'volume': 0,
#     'adjclose': 17805.0,
#     'formatted_date': '2003-10-08'},
#    {'date': 1065704400,
#     'high': 18060.0,
#     'low': 17553.0,
#     'open': 17805.0,
#     'close': 17708.0,
#     'volume': 0,
#     'adjclose': 17708.0,
#     'formatted_date': '2003-10-09'},
#    {'date': 1065790800,
#     'high': 17834.0,
#     'low': 17496.0,
#     'open': 17699.0,
#     'close': 17676.0,
#     'volume': 0,
#     'adjclose': 17676.0,
#     'formatted_date': '2003-10-10'},
#    {'date': 1066050000,
#     'high': 18075.0,
#     'low': 17676.0,
#     'open': 17676.0,
#     'close': 18062.0,
#     'volume': 0,
#     'adjclose': 18062.0,
#     'formatted_date': '2003-10-13'},
#    {'date': 1066136400,
#     'high': 18246.0,
#     'low': 18063.0,
#     'open': 18063.0,
#     'close': 18178.0,
#     'volume': 0,
#     'adjclose': 18178.0,
#     'formatted_date': '2003-10-14'},
#    {'date': 1066222800,
#     'high': 18313.0,
#     'low': 17819.0,
#     'open': 18176.0,
#     'close': 17942.0,
#     'volume': 0,
#     'adjclose': 17942.0,
#     'formatted_date': '2003-10-15'},
#    {'date': 1066309200,
#     'high': 18075.0,
#     'low': 17834.0,
#     'open': 17944.0,
#     'close': 17955.0,
#     'volume': 0,
#     'adjclose': 17955.0,
#     'formatted_date': '2003-10-16'},
#    {'date': 1066395600,
#     'high': 17946.0,
#     'low': 17679.0,
#     'open': 17923.0,
#     'close': 17791.0,
#     'volume': 0,
#     'adjclose': 17791.0,
#     'formatted_date': '2003-10-17'},
#    {'date': 1066651200,
#     'high': 18399.0,
#     'low': 17770.0,
#     'open': 17791.0,
#     'close': 18370.0,
#     'volume': 0,
#     'adjclose': 18370.0,
#     'formatted_date': '2003-10-20'},
#    {'date': 1066737600,
#     'high': 18660.0,
#     'low': 18370.0,
#     'open': 18370.0,
#     'close': 18449.0,
#     'volume': 0,
#     'adjclose': 18449.0,
#     'formatted_date': '2003-10-21'},
#    {'date': 1066824000,
#     'high': 18449.0,
#     'low': 18221.0,
#     'open': 18449.0,
#     'close': 18235.0,
#     'volume': 0,
#     'adjclose': 18235.0,
#     'formatted_date': '2003-10-22'},
#    {'date': 1066910400,
#     'high': 18235.0,
#     'low': 17592.0,
#     'open': 18235.0,
#     'close': 17690.0,
#     'volume': 0,
#     'adjclose': 17690.0,
#     'formatted_date': '2003-10-23'},
#    {'date': 1066996800,
#     'high': 17835.0,
#     'low': 17340.0,
#     'open': 17687.0,
#     'close': 17814.0,
#     'volume': 0,
#     'adjclose': 17814.0,
#     'formatted_date': '2003-10-24'},
#    {'date': 1067256000,
#     'high': 17964.0,
#     'low': 17664.0,
#     'open': 17820.0,
#     'close': 17750.0,
#     'volume': 0,
#     'adjclose': 17750.0,
#     'formatted_date': '2003-10-27'},
#    {'date': 1067342400,
#     'high': 18228.0,
#     'low': 17691.0,
#     'open': 17750.0,
#     'close': 18228.0,
#     'volume': 0,
#     'adjclose': 18228.0,
#     'formatted_date': '2003-10-28'},
#    {'date': 1067428800,
#     'high': 18454.0,
#     'low': 17945.0,
#     'open': 18228.0,
#     'close': 17945.0,
#     'volume': 0,
#     'adjclose': 17945.0,
#     'formatted_date': '2003-10-29'},
#    {'date': 1067515200,
#     'high': 18193.0,
#     'low': 17731.0,
#     'open': 17945.0,
#     'close': 18094.0,
#     'volume': 0,
#     'adjclose': 18094.0,
#     'formatted_date': '2003-10-30'},
#    {'date': 1067601600,
#     'high': 18218.0,
#     'low': 17912.0,
#     'open': 18095.0,
#     'close': 17982.0,
#     'volume': 0,
#     'adjclose': 17982.0,
#     'formatted_date': '2003-10-31'},
#    ...]}}

# %%
# Generate the dataset with the historical prices for all the tickers.
ibov_prices = []
for ticker, historical_data in ibov_data.items():
    if "prices" in historical_data and len(historical_data["prices"]) > 0:
        for index_price in historical_data["prices"]:
            data = index_price.copy()
            data["ticker"] = ticker
            data["type"] = "INDEX"
            ibov_prices.append(data)
                        
stock_prices_df = pd.DataFrame(stock_prices)
# Convert the 'formatted_date' column type from string to datetime
stock_prices_df['formatted_date'] =  pd.to_datetime(stock_prices_df['formatted_date'], format='%Y-%m-%d')

# %%
GEBR10Y_data
# Out:
# {'^GEBR10Y': {'eventsData': {}}}
